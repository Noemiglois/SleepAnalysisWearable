# %% [markdown]
# <center> <h1>PREDICCIÓN DEL SUEÑO</h1> </center>
# <center> <h3>CREACIÓN DEL DATAFRAME</h3> </center>
# <center> <h4>Noemi González, Roberto Holgado y Carmen Plaza</h4> </center>
#
# ### Índice de contenidos de este Notebook
#
# En este Notebook se realiza el preprocesado de las 3 características: frecuencia cardíaca, aceleración y pasos. Se extraen características a partir de ellas y se almacenan en un dataframe 'features' que contiene las características de los 31 sujetos. Para ello se siguen los siguientes pasos:
#
#     1. Creación ventana deslizante
#     2. Extracción de características y obtención dataframe
#     3. Visualización datos dataframe

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from random import sample
import statistics as stats
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# Se cargan los datos de las distintas carpetas en listas:

# %%
# LISTAS CON LOS NOMBRES DE TODOS LOS ARCHIVOS .txt
sujetos_sueño=[]
for file in (os.listdir("labels")):
    sujetos_sueño.append(os.path.join("labels",file))
    sujetos_sueño=sorted(sujetos_sueño)
    
sujetos_frec_card=[]
for file in os.listdir("heart_rate"):
    sujetos_frec_card.append(os.path.join("heart_rate",file))

sujetos_pasos=[]
for file in os.listdir("steps"):
    sujetos_pasos.append(os.path.join("steps",file))

sujetos_movimiento=[]
for file in os.listdir("motion"):
    sujetos_movimiento.append(os.path.join("motion",file))

# %% [markdown]
# ### 1. Creación ventana deslizante

# %% [markdown]
# La ventana deslizante recorre la señal fisiológica introducida como parámetro de entrada (*signal*). La función *'get_window'*, además, toma como datos de entrada el tamaño de la ventana en segundos (*w_size*) y la longitud de la señal de las etiquetas del sueño (*n_sueño*).
#
# Esta función recorre el eje de tiempo de la señal deseada y va asignando índices (True o False) según se cumpla o no el parámetro establecido en el segundo bucle for. Dicha condición depende directamente del tamaño de ventana que se seleccione.
# * Si el eje de tiempo está entre los valores 'a' y 'b' se asiga True
# * Si esa condición no se cumplese asigna False

# %%
def get_window(w_size,signal,n_sueño):
    time = signal["Tiempo"]
    f_list=[]
    
    for i in range(n_sueño):
        a = w_size*(1+i)
        b = w_size*(2+i)

        idx=[]
        for t in time:
            if t>a and t<b:
                idx.append(True)
            else:
                idx.append(False)
        
        f = signal[idx]
        f_list.append(f)
    
    return f_list

# %% [markdown]
# En esta ocasión se selecciona una *w_size*=**30 segundos**, para tener una característica cada 30s y así hacer coincidir la cantidad de los datos adquiridos por medio del Apple Watch con los datos recogidos por la PSG.

# %% [markdown]
# ### 2. Extracción de características y obtención del dataframe

# %% [markdown]
# A continuación se detallan las características extraídas con la ventana deslizante a partir de las originales:
#
# * **feat1: min_list**: frecuencias cardíacas mínimas.
# * **feat2: max_list**: frecuencias cardíacas máximas.
# * **feat3: mean_list**: frecuencias cardíacas medias.
#
# * **feat4: mean_sqrt_acc**: aceleraciones medias.
#
# * **feat5: min_accx**: aceleraciones eje x mínimas.
# * **feat6: max_accx**: aceleraciones eje x máximas.
# * **feat7: mean_accx**: aceleraciones eje x medias.
#
# * **feat8: min_accy**: aceleraciones eje y mínimas.
# * **feat9: max_accy**: aceleraciones eje y máximas.
# * **feat10: mean_accy**: aceleraciones eje y medias.
#
# * **feat11: min_accz**: aceleraciones eje z mínimas.
# * **feat12: max_accz**: aceleraciones eje z máximas.
# * **feat13: mean_accz**: aceleraciones eje z medias.
#
# Con todas las características se ha creado un dataframe que incluye a todos los sujetos. Además, se han añadido una columna con los **identificadores de cada sujeto** para tener los datos localizados en todo momento.
#
# La columna de **etiquetas binarias** es una modificación de la columna etiquetas. Se ha realizado esta modificación para crear un clasificador de salida binaria como primera aproximación.

# %%
df = []
for a, (i,j,k,l) in  enumerate(zip(sujetos_sueño,sujetos_frec_card,sujetos_pasos,sujetos_movimiento)):
    w_size = 30
    
    
    #SUEÑO
    sueño = pd.read_csv(i, delimiter=' ')
    sueño.columns = ["Tiempo","Etiqueta"]
    n_sueño = len(sueño)
    
    #SUEÑO BINARIO
    sueño_bin = sueño.replace(to_replace =[-1,5],  value =0) 
    sueño_bin = sueño_bin.replace(to_replace =[2,3,4],  value =1)    #Etiquetas binarias 0-sueño ligero 1-sueño profundo
    bin_labels = sueño_bin["Etiqueta"]
    
    #SUEÑO MULTICLASE
    sueño_multi = sueño.replace(to_replace =[-1],  value =0) 
    sueño_multi = sueño_multi.replace(to_replace =[4],  value =3)    #Etiquetas multiclase 0-sueño muy ligero
                                                                    #1,2,3-sueño profundo 5-sueño ligero(rem)
    multi_labels = sueño_multi["Etiqueta"]
    
    #ID_LIST
    labels = sueño["Etiqueta"]
    id_list = [a]*len(labels)
    
    #FRECUENCIA CARDIACA
    frec_card = pd.read_csv(j)
    frec_card.columns = ["Tiempo","Frec card"]
    frec_card=frec_card[frec_card["Tiempo"]>0]

    signal = frec_card
    f_list = get_window(w_size,signal,n_sueño)

    fc_mean_list = []
    fc_min_list = []
    fc_max_list = []

    for f in f_list:
        fc_mean_list.append(round(f['Frec card'].mean(),2))
        fc_min_list.append(round(f['Frec card'].min(),2))
        fc_max_list.append(round(f['Frec card'].max(),2))
    
    feat1 = fc_min_list
    feat2 = fc_max_list
    feat3 = fc_mean_list
    
    #ACCELERACION
    mov=pd.read_csv(l, delimiter=' ')
    mov.columns=["Tiempo","Ac_x","Ac_y","Ac_z"]
    mov_t=mov[mov['Tiempo']>0]
    
    mov_t=mov_t.sample(frac=.1)
    mov_t=mov_t.sort_values('Tiempo')
    raiz_movto= np.sqrt(mov_t.Ac_x**2 + mov_t.Ac_y**2 + mov_t.Ac_z**2)
    mov_t['Raiz_movto'] = raiz_movto
    
    signal=mov_t
    acc_list= get_window(w_size,signal,n_sueño)
    
    mean_sqrt_acc=[]
    
    min_accx=[]
    max_accx=[]
    mean_accx=[]
    
    min_accy=[]
    max_accy=[]
    mean_accy=[]
    
    min_accz=[]
    max_accz=[]
    mean_accz=[]
    
    for f in acc_list:
        mean_sqrt_acc.append(round(f['Raiz_movto'].mean(),2))
        
        min_accx.append(round(f['Ac_x'].min(),2))
        max_accx.append(round(f['Ac_x'].max(),2))
        mean_accx.append(round(f['Ac_x'].mean(),2))
        
        min_accy.append(round(f['Ac_y'].min(),2))
        max_accy.append(round(f['Ac_y'].max(),2))
        mean_accy.append(round(f['Ac_y'].mean(),2))
        
        min_accz.append(round(f['Ac_z'].min(),2))
        max_accz.append(round(f['Ac_z'].max(),2))
        mean_accz.append(round(f['Ac_z'].mean(),2))
        
    feat4=mean_sqrt_acc
    
    feat5=min_accx
    feat6=max_accx
    feat7=mean_accx
    
    feat8=min_accy
    feat9=max_accy
    feat10=mean_accy
    
    feat11=min_accz
    feat12=max_accz
    feat13=mean_accz
    
    datos = {'Min_hr': feat1, "Max_hr": feat2,"Mean_hr":feat3,'Men_acc_sqrt': feat4,
             "Min_acc_x": feat5,"Max_acc_x":feat6,"Mean_acc_x": feat7,
             "Min_acc_y": feat8,"Max_acc_y":feat9,"Mean_acc_y":feat10,
             "Min_acc_z": feat11,"Max_acc_z":feat12,"Mean_acc_z":feat13,
            "Etiquetas binarias":bin_labels,"Etiquetas multiclase":multi_labels, "ID":id_list}
    
    datos_sujeto = pd.DataFrame(data=datos)
    df.append(datos_sujeto)

# %%
print(len(df))
# Out:
# 31

# %%
df
# Out:
# [     Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      49.0    54.0    50.83           1.0       0.40       0.41         0.4
#  1      50.0    54.0    52.40           1.0       0.40       0.41         0.4
#  2      53.0    54.0    53.83           1.0       0.39       0.41         0.4
#  3      56.0    68.0    60.50           1.0       0.40       0.41         0.4
#  4      51.0    52.0    51.67           1.0       0.40       0.40         0.4
#  ..      ...     ...      ...           ...        ...        ...         ...
#  946     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  947     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  948    69.0    69.0    69.00           NaN        NaN        NaN         NaN
#  949     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  950     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.45       0.46        0.46      -0.80      -0.79       -0.79
#  1         0.45       0.47        0.46      -0.79      -0.78       -0.79
#  2         0.46       0.47        0.47      -0.80      -0.78       -0.79
#  3         0.46       0.48        0.47      -0.79      -0.78       -0.79
#  4         0.46       0.47        0.47      -0.79      -0.78       -0.79
#  ..         ...        ...         ...        ...        ...         ...
#  946        NaN        NaN         NaN        NaN        NaN         NaN
#  947        NaN        NaN         NaN        NaN        NaN         NaN
#  948        NaN        NaN         NaN        NaN        NaN         NaN
#  949        NaN        NaN         NaN        NaN        NaN         NaN
#  950        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   0
#  1                     0                     0   0
#  2                     0                     0   0
#  3                     0                     0   0
#  4                     0                     0   0
#  ..                  ...                   ...  ..
#  946                   0                     0   0
#  947                   0                     0   0
#  948                   0                     0   0
#  949                   0                     0   0
#  950                   0                     0   0
#
#  [951 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        69      77    74.29           NaN        NaN        NaN         NaN
#  1        75      77    76.40           NaN        NaN        NaN         NaN
#  2        75      77    75.67           NaN        NaN        NaN         NaN
#  3        74      75    74.50           NaN        NaN        NaN         NaN
#  4        70      73    71.17           NaN        NaN        NaN         NaN
#  ..      ...     ...      ...           ...        ...        ...         ...
#  962      71      82    74.50          0.99      -0.04      -0.03       -0.04
#  963      75      79    76.83          0.99      -0.04      -0.03       -0.04
#  964      70      74    72.20          0.99      -0.04      -0.03       -0.04
#  965      70      74    71.83          0.99      -0.04      -0.03       -0.04
#  966      75      79    77.20          1.00      -0.77       0.18       -0.16
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0          NaN        NaN         NaN        NaN        NaN         NaN
#  1          NaN        NaN         NaN        NaN        NaN         NaN
#  2          NaN        NaN         NaN        NaN        NaN         NaN
#  3          NaN        NaN         NaN        NaN        NaN         NaN
#  4          NaN        NaN         NaN        NaN        NaN         NaN
#  ..         ...        ...         ...        ...        ...         ...
#  962      -0.28      -0.26       -0.27       0.95       0.96        0.96
#  963      -0.28      -0.26       -0.27       0.95       0.96        0.96
#  964      -0.28      -0.27       -0.27       0.95       0.96        0.96
#  965      -0.28      -0.27       -0.27       0.95       0.96        0.96
#  966      -0.69       1.15        0.16      -1.00       1.30       -0.07
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   1
#  1                     0                     0   1
#  2                     0                     0   1
#  3                     0                     0   1
#  4                     0                     0   1
#  ..                  ...                   ...  ..
#  962                   1                     2   1
#  963                   1                     2   1
#  964                   1                     2   1
#  965                   0                     0   1
#  966                   0                     0   1
#
#  [967 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      68.0    73.0    70.33          1.00      -0.32      -0.14       -0.17
#  1      68.0    68.0    68.00          1.00      -0.21      -0.03       -0.12
#  2      67.0    73.0    68.50          1.00      -0.43       0.98        0.19
#  3      67.0    74.0    69.83          1.02      -3.89       1.00        0.14
#  4      65.0    66.0    65.17          1.00      -0.53       0.51       -0.19
#  ..      ...     ...      ...           ...        ...        ...         ...
#  959    64.0    65.0    64.83          1.00      -0.08      -0.07       -0.08
#  960    65.0    66.0    65.40          1.00      -0.08      -0.07       -0.08
#  961    60.0    65.0    63.43          1.00      -0.08      -0.07       -0.08
#  962    61.0    63.0    62.40          1.00      -0.08      -0.07       -0.08
#  963    64.0    65.0    64.83          1.00      -0.08      -0.07       -0.08
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.84       1.39        0.86      -0.51       0.17       -0.48
#  1         0.84       1.04        0.92      -0.51       0.42        0.18
#  2        -0.29       1.95        0.76      -1.05       1.15       -0.18
#  3        -0.46       2.00        0.55      -3.38       1.27       -0.37
#  4        -0.32       1.63        0.80      -0.85      -0.07       -0.54
#  ..         ...        ...         ...        ...        ...         ...
#  959      -0.11      -0.10       -0.10      -1.00      -0.99       -0.99
#  960      -0.11      -0.09       -0.10      -1.00      -0.99       -0.99
#  961      -0.11      -0.09       -0.10      -1.00      -0.99       -0.99
#  962      -0.11      -0.10       -0.10      -1.00      -0.99       -0.99
#  963      -0.11      -0.10       -0.10      -1.00      -0.99       -0.99
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   2
#  1                     0                     0   2
#  2                     0                     0   2
#  3                     0                     0   2
#  4                     0                     0   2
#  ..                  ...                   ...  ..
#  959                   0                     0   2
#  960                   0                     0   2
#  961                   0                     0   2
#  962                   0                     0   2
#  963                   0                     0   2
#
#  [964 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      59.0    78.0    65.50          1.00      -0.02       0.10        0.05
#  1      59.0    60.0    59.50          1.00      -0.84       0.05       -0.42
#  2      57.0    59.0    58.00          1.00      -0.86       0.09       -0.39
#  3      59.0    61.0    59.60          1.00      -0.35       0.36        0.05
#  4      57.0    62.0    58.86          1.01      -0.76       0.92        0.17
#  ..      ...     ...      ...           ...        ...        ...         ...
#  984    49.0    65.0    52.40          1.00      -0.26      -0.25       -0.26
#  985    49.0    50.0    49.50          1.00      -0.26      -0.25       -0.26
#  986    48.0    49.0    48.80          1.00      -0.26      -0.25       -0.25
#  987    47.0    49.0    48.00          1.01      -0.82       0.88        0.19
#  988   103.0   107.0   104.20          1.01      -0.83       1.13        0.09
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.22       1.01        0.53      -0.98      -0.11       -0.81
#  1         0.07       1.30        0.60      -1.00       0.03       -0.42
#  2         0.32       0.98        0.58      -0.96      -0.16       -0.50
#  3         0.25       1.08        0.70      -1.19      -0.26       -0.66
#  4        -0.09       1.14        0.59      -0.94       0.27       -0.59
#  ..         ...        ...         ...        ...        ...         ...
#  984      -0.50      -0.50       -0.50      -0.84      -0.82       -0.83
#  985      -0.52      -0.46       -0.50      -0.86      -0.81       -0.83
#  986      -0.52      -0.47       -0.52      -0.84      -0.81       -0.82
#  987      -0.93       0.48       -0.27      -1.25      -0.24       -0.80
#  988      -0.70       1.22        0.27      -1.03       0.52       -0.56
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   3
#  1                     0                     0   3
#  2                     0                     0   3
#  3                     0                     0   3
#  4                     0                     0   3
#  ..                  ...                   ...  ..
#  984                   1                     1   3
#  985                   0                     0   3
#  986                   0                     0   3
#  987                   0                     0   3
#  988                   0                     0   3
#
#  [989 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      73.0    74.0    73.60           1.0      -0.36      -0.35       -0.35
#  1      72.0    75.0    73.33           1.0      -0.36      -0.35       -0.35
#  2      72.0    76.0    72.67           1.0      -0.36      -0.35       -0.35
#  3      71.0    74.0    71.67           1.0      -0.36      -0.35       -0.35
#  4      71.0    72.0    71.83           1.0      -0.36      -0.35       -0.36
#  ..      ...     ...      ...           ...        ...        ...         ...
#  982    73.0    74.0    73.40           1.0      -0.28      -0.27       -0.28
#  983    74.0    76.0    74.80           1.0      -0.28      -0.27       -0.28
#  984    71.0    76.0    73.33           1.0      -0.28      -0.27       -0.28
#  985    74.0    77.0    75.71           1.0      -0.28      -0.27       -0.28
#  986    74.0    75.0    74.60           1.0      -0.28      -0.27       -0.28
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.01       0.01        0.01       0.93       0.94        0.93
#  1         0.01       0.01        0.01       0.93       0.94        0.93
#  2         0.01       0.01        0.01       0.93       0.94        0.93
#  3         0.01       0.01        0.01       0.93       0.94        0.93
#  4         0.01       0.01        0.01       0.93       0.94        0.93
#  ..         ...        ...         ...        ...        ...         ...
#  982      -0.31      -0.29       -0.30      -0.92      -0.91       -0.92
#  983      -0.31      -0.29       -0.30      -0.92      -0.91       -0.92
#  984      -0.31      -0.28       -0.30      -0.93      -0.91       -0.92
#  985      -0.31      -0.29       -0.30      -0.92      -0.91       -0.92
#  986      -0.31      -0.29       -0.30      -0.92      -0.91       -0.92
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   4
#  1                     0                     0   4
#  2                     0                     0   4
#  3                     0                     0   4
#  4                     0                     0   4
#  ..                  ...                   ...  ..
#  982                   0                     0   4
#  983                   0                     0   4
#  984                   0                     0   4
#  985                   0                     0   4
#  986                   0                     0   4
#
#  [987 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      49.0    49.0    49.00          1.01      -0.77      -0.04       -0.55
#  1      48.0    65.0    53.67          1.00      -0.40      -0.37       -0.38
#  2      47.0    48.0    47.40          0.99      -0.81       0.14       -0.39
#  3      47.0    59.0    57.00          1.01      -1.12       0.15       -0.57
#  4      49.0    56.0    51.50          1.00      -0.42      -0.30       -0.36
#  ..      ...     ...      ...           ...        ...        ...         ...
#  977    46.0    47.0    46.20          1.00      -0.34      -0.33       -0.34
#  978    44.0    46.0    45.50          1.00      -0.34      -0.33       -0.34
#  979    43.0    44.0    43.80          1.00      -0.34      -0.33       -0.34
#  980    44.0    44.0    44.00          1.00      -0.48      -0.07       -0.34
#  981    86.0    86.0    86.00          1.00      -0.99       0.04       -0.32
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.23       0.35       -0.55      -1.29       0.06       -0.57
#  1        -0.03      -0.00       -0.02      -0.93      -0.91       -0.92
#  2        -1.45      -0.01       -0.27      -1.14       0.59       -0.65
#  3        -1.00       0.16       -0.50      -1.83       0.62       -0.28
#  4        -0.50      -0.23       -0.39      -0.97      -0.74       -0.84
#  ..         ...        ...         ...        ...        ...         ...
#  977      -0.18      -0.16       -0.17      -0.93      -0.91       -0.93
#  978      -0.18      -0.16       -0.17      -0.93      -0.91       -0.92
#  979      -0.18      -0.16       -0.17      -0.93      -0.91       -0.93
#  980      -0.73       0.44       -0.26      -0.96      -0.53       -0.88
#  981      -0.87      -0.06       -0.30      -0.99       1.09       -0.40
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   5
#  1                     0                     0   5
#  2                     0                     0   5
#  3                     0                     0   5
#  4                     0                     0   5
#  ..                  ...                   ...  ..
#  977                   1                     2   5
#  978                   0                     5   5
#  979                   0                     0   5
#  980                   0                     0   5
#  981                   0                     0   5
#
#  [982 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        82      84    83.00          1.01      -1.00      -0.22       -0.46
#  1        75      80    78.00          0.99      -0.76      -0.20       -0.38
#  2        75      80    76.50          0.99      -1.04      -0.34       -0.51
#  3        70      75    71.80          1.00      -1.08      -0.88       -0.97
#  4        68      71    69.67          1.00      -1.01      -0.31       -0.78
#  ..      ...     ...      ...           ...        ...        ...         ...
#  963      59      66    62.33          0.99      -0.23      -0.22       -0.23
#  964      56      59    57.50          0.99      -0.23      -0.23       -0.23
#  965      57      63    60.60          0.99      -0.23      -0.22       -0.23
#  966      61      64    62.50          0.99      -0.23      -0.23       -0.23
#  967      64      68    66.33          0.99      -0.23      -0.22       -0.23
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.99       0.28       -0.83      -0.75       0.98        0.15
#  1        -0.98      -0.33       -0.90      -0.58       0.66        0.01
#  2        -1.26       0.32       -0.72      -0.60       0.45       -0.02
#  3        -0.16       0.10       -0.06      -0.33      -0.09       -0.23
#  4        -1.13       0.39       -0.11      -1.05      -0.08       -0.36
#  ..         ...        ...         ...        ...        ...         ...
#  963      -0.97      -0.96       -0.96      -0.10      -0.10       -0.10
#  964      -0.97      -0.96       -0.96      -0.10      -0.10       -0.10
#  965      -0.97      -0.96       -0.96      -0.10      -0.08       -0.10
#  966      -0.97      -0.96       -0.96      -0.10      -0.09       -0.10
#  967      -0.99      -0.95       -0.96      -0.11      -0.09       -0.09
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   6
#  1                     0                     0   6
#  2                     0                     0   6
#  3                     0                     0   6
#  4                     0                     0   6
#  ..                  ...                   ...  ..
#  963                   0                     0   6
#  964                   0                     0   6
#  965                   0                     0   6
#  966                   0                     0   6
#  967                   0                     0   6
#
#  [968 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      78.0    80.0    79.20          0.99      -1.00       0.05       -0.12
#  1      73.0    84.0    78.67          0.99      -0.05      -0.05       -0.05
#  2      72.0    83.0    74.83          0.99      -0.79      -0.03       -0.13
#  3      75.0    80.0    77.00          0.99      -0.12      -0.10       -0.11
#  4      75.0    76.0    75.50          0.99      -0.11      -0.10       -0.10
#  ..      ...     ...      ...           ...        ...        ...         ...
#  411    86.0    87.0    86.67          0.99      -0.11      -0.10       -0.11
#  412    86.0    88.0    87.00          0.99      -0.11      -0.10       -0.11
#  413    85.0    87.0    86.14          0.99      -0.11      -0.10       -0.11
#  414    87.0    88.0    87.20          0.99      -0.11      -0.10       -0.11
#  415    85.0    87.0    86.00          0.99      -0.11      -0.10       -0.11
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.50       0.28       -0.15      -1.20       0.02       -0.93
#  1        -0.12      -0.08       -0.11      -0.99      -0.98       -0.99
#  2        -0.35       0.39       -0.14      -1.06      -0.52       -0.94
#  3        -0.32      -0.28       -0.30      -0.95      -0.93       -0.94
#  4        -0.31      -0.30       -0.30      -0.94      -0.94       -0.94
#  ..         ...        ...         ...        ...        ...         ...
#  411      -0.21      -0.19       -0.20      -0.97      -0.96       -0.97
#  412      -0.20      -0.20       -0.20      -0.97      -0.97       -0.97
#  413      -0.20      -0.19       -0.20      -0.97      -0.97       -0.97
#  414      -0.20      -0.20       -0.20      -0.97      -0.97       -0.97
#  415      -0.20      -0.20       -0.20      -0.97      -0.97       -0.97
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   7
#  1                     0                     0   7
#  2                     0                     0   7
#  3                     0                     0   7
#  4                     0                     0   7
#  ..                  ...                   ...  ..
#  411                   1                     2   7
#  412                   1                     2   7
#  413                   1                     2   7
#  414                   1                     2   7
#  415                   1                     2   7
#
#  [416 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        63      65    63.50          1.00      -0.92      -0.62       -0.74
#  1        57      61    59.17          1.00      -0.94      -0.49       -0.70
#  2        58      61    59.43          1.00      -1.19      -0.16       -0.68
#  3        59      60    59.17          1.00      -0.27      -0.26       -0.27
#  4        54      59    55.67          1.00      -0.27      -0.26       -0.26
#  ..      ...     ...      ...           ...        ...        ...         ...
#  971      50      55    53.00          1.00      -0.51      -0.49       -0.50
#  972      55      59    57.17          1.00      -0.51      -0.49       -0.50
#  973      51      54    52.17          1.00      -0.51      -0.49       -0.50
#  974      51      51    51.00          1.01      -1.23       0.21       -0.33
#  975      51      64    57.86          1.00      -0.07      -0.05       -0.06
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.32       0.79        0.25      -0.72      -0.14       -0.53
#  1        -0.35       0.96        0.34      -0.80       0.00       -0.49
#  2        -0.84       0.61       -0.01      -1.11       0.55       -0.49
#  3         0.47       0.49        0.48      -0.85      -0.83       -0.84
#  4         0.47       0.48        0.48      -0.85      -0.84       -0.84
#  ..         ...        ...         ...        ...        ...         ...
#  971       0.10       0.15        0.11      -0.87      -0.84       -0.86
#  972       0.10       0.15        0.12      -0.87      -0.85       -0.86
#  973       0.10       0.15        0.12      -0.87      -0.85       -0.86
#  974      -0.52       0.31       -0.07      -1.58       0.62       -0.86
#  975      -0.01       0.01        0.00      -1.00      -0.99       -1.00
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   8
#  1                     0                     0   8
#  2                     0                     0   8
#  3                     0                     0   8
#  4                     0                     0   8
#  ..                  ...                   ...  ..
#  971                   0                     5   8
#  972                   0                     5   8
#  973                   0                     5   8
#  974                   0                     0   8
#  975                   0                     0   8
#
#  [976 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      58.0    68.0    61.00          1.01      -0.86       0.87       -0.57
#  1      74.0    83.0    79.43          1.04      -1.29      -0.13       -0.78
#  2      76.0    81.0    79.17          1.00      -1.05      -0.41       -0.75
#  3      79.0    87.0    83.00          1.02      -1.12       0.11       -0.76
#  4      73.0    89.0    80.67          1.00      -0.82      -0.80       -0.80
#  ..      ...     ...      ...           ...        ...        ...         ...
#  504    60.0    61.0    60.20           NaN        NaN        NaN         NaN
#  505    59.0    61.0    59.57           NaN        NaN        NaN         NaN
#  506    57.0    59.0    58.17           NaN        NaN        NaN         NaN
#  507    58.0    59.0    58.40           NaN        NaN        NaN         NaN
#  508    57.0    58.0    57.33          0.99      -0.33      -0.33       -0.33
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.12       0.80        0.61      -0.74       1.56       -0.01
#  1        -1.19       0.82       -0.20      -2.24       1.66       -0.23
#  2        -0.55       0.93        0.37      -0.70       0.56        0.06
#  3        -1.25       1.18       -0.14      -1.97       0.97       -0.02
#  4        -0.56      -0.54       -0.56      -0.20      -0.18       -0.19
#  ..         ...        ...         ...        ...        ...         ...
#  504        NaN        NaN         NaN        NaN        NaN         NaN
#  505        NaN        NaN         NaN        NaN        NaN         NaN
#  506        NaN        NaN         NaN        NaN        NaN         NaN
#  507        NaN        NaN         NaN        NaN        NaN         NaN
#  508      -0.46      -0.45       -0.46      -0.82      -0.82       -0.82
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   9
#  1                     0                     0   9
#  2                     0                     0   9
#  3                     0                     0   9
#  4                     0                     0   9
#  ..                  ...                   ...  ..
#  504                   0                     0   9
#  505                   0                     0   9
#  506                   0                     0   9
#  507                   0                     0   9
#  508                   0                     0   9
#
#  [509 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      75.0    77.0    76.33          1.00      -0.55       1.39        0.48
#  1      76.0    88.0    78.40          1.02      -1.17       1.22       -0.29
#  2      83.0    86.0    85.50          1.00      -1.16       0.37       -0.55
#  3      70.0    77.0    71.67          0.99      -0.59      -0.54       -0.56
#  4      68.0    69.0    68.67          0.99      -0.57      -0.55       -0.56
#  ..      ...     ...      ...           ...        ...        ...         ...
#  964    65.0    71.0    67.40          1.00      -0.38      -0.15       -0.27
#  965    62.0    66.0    64.50          1.00      -0.43      -0.27       -0.29
#  966    61.0    70.0    63.50          1.00      -0.50       0.01       -0.09
#  967    60.0    62.0    61.33          1.00      -0.08      -0.07       -0.07
#  968    60.0    61.0    60.50          1.00      -0.08      -0.07       -0.07
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.32       1.01        0.61      -0.92      -0.12       -0.46
#  1        -0.71       1.25        0.23      -1.31       0.93       -0.20
#  2        -1.03       0.55       -0.26      -0.93       0.25       -0.61
#  3        -0.43      -0.30       -0.39      -0.76      -0.70       -0.72
#  4        -0.42      -0.39       -0.40      -0.72      -0.70       -0.71
#  ..         ...        ...         ...        ...        ...         ...
#  964      -1.03      -0.59       -0.81       0.28       0.91        0.50
#  965      -0.97      -0.38       -0.80      -0.83       0.51        0.39
#  966      -1.02      -0.52       -0.87      -0.00       0.74        0.47
#  967      -0.88      -0.87       -0.87       0.47       0.49        0.48
#  968      -0.88      -0.87       -0.87       0.47       0.48        0.48
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  10
#  1                     0                     0  10
#  2                     0                     0  10
#  3                     0                     0  10
#  4                     0                     0  10
#  ..                  ...                   ...  ..
#  964                   0                     0  10
#  965                   0                     0  10
#  966                   0                     0  10
#  967                   0                     0  10
#  968                   0                     0  10
#
#  [969 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      56.0    59.0    58.00          1.01      -2.23       1.02       -0.39
#  1      54.0    55.0    54.86          0.99      -0.37      -0.36       -0.36
#  2      54.0    54.0    54.00          0.99      -0.38      -0.35       -0.37
#  3      54.0    59.0    56.00          0.99      -0.39      -0.35       -0.37
#  4      52.0    54.0    53.17          0.99      -0.38      -0.37       -0.37
#  ..      ...     ...      ...           ...        ...        ...         ...
#  974    57.0    62.0    60.20          1.00      -0.11      -0.11       -0.11
#  975    59.0    63.0    60.50          1.00      -0.12      -0.11       -0.11
#  976    61.0    64.0    62.40          1.00      -0.11      -0.11       -0.11
#  977    58.0    62.0    59.00          1.00      -0.12      -0.11       -0.11
#  978    58.0    58.0    58.00          1.00      -0.11      -0.11       -0.11
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.19       1.07        0.12      -1.09       0.76       -0.79
#  1         0.12       0.14        0.13      -0.92      -0.91       -0.91
#  2         0.12       0.18        0.14      -0.92      -0.89       -0.91
#  3         0.12       0.36        0.23      -0.92      -0.86       -0.89
#  4         0.24       0.27        0.25      -0.89      -0.87       -0.88
#  ..         ...        ...         ...        ...        ...         ...
#  974      -0.96      -0.95       -0.96       0.26       0.27        0.26
#  975      -0.96      -0.95       -0.96       0.26       0.27        0.26
#  976      -0.96      -0.95       -0.96       0.26       0.27        0.26
#  977      -0.96      -0.95       -0.96       0.26       0.27        0.26
#  978      -0.96      -0.95       -0.96       0.26       0.26        0.26
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  11
#  1                     0                     0  11
#  2                     0                     0  11
#  3                     0                     0  11
#  4                     0                     0  11
#  ..                  ...                   ...  ..
#  974                   0                     5  11
#  975                   0                     5  11
#  976                   0                     5  11
#  977                   0                     5  11
#  978                   0                     5  11
#
#  [979 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        84      95    87.20           1.0      -0.42      -0.19       -0.33
#  1        78      85    80.50           1.0      -0.51      -0.29       -0.41
#  2        82      84    82.83           1.0      -0.51      -0.35       -0.39
#  3        82      86    83.17           1.0      -0.46      -0.35       -0.40
#  4        86      87    86.33           1.0      -0.52      -0.09       -0.32
#  ..      ...     ...      ...           ...        ...        ...         ...
#  561      75      77    75.83           1.0      -0.44      -0.44       -0.44
#  562      75      77    76.50           1.0      -0.44      -0.44       -0.44
#  563      73      75    73.67           1.0      -0.45      -0.44       -0.44
#  564      72      76    74.00           1.0      -0.45      -0.44       -0.44
#  565      75      75    75.00           1.0      -0.45      -0.43       -0.44
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.76       1.04        0.90      -0.12       0.56        0.24
#  1         0.85       0.99        0.90      -0.09       0.22        0.07
#  2         0.83       0.96        0.92      -0.18       0.05        0.00
#  3         0.82       0.97        0.91      -0.05       0.34        0.12
#  4         0.32       1.00        0.83      -0.94       0.45       -0.12
#  ..         ...        ...         ...        ...        ...         ...
#  561      -0.53      -0.52       -0.53       0.72       0.73        0.72
#  562      -0.53      -0.52       -0.53       0.72       0.73        0.72
#  563      -0.53      -0.52       -0.53       0.72       0.73        0.72
#  564      -0.53      -0.52       -0.53       0.72       0.73        0.72
#  565      -0.53      -0.52       -0.53       0.72       0.73        0.72
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  12
#  1                     0                     0  12
#  2                     0                     0  12
#  3                     0                     0  12
#  4                     0                     0  12
#  ..                  ...                   ...  ..
#  561                   0                     0  12
#  562                   0                     0  12
#  563                   0                     0  12
#  564                   0                     0  12
#  565                   0                     0  12
#
#  [566 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      97.0   104.0   100.00          1.00      -0.01       0.00       -0.00
#  1      96.0    98.0    97.20          1.00      -0.01       0.00       -0.00
#  2      95.0    97.0    95.57          1.00      -0.01       0.00       -0.00
#  3      96.0    97.0    96.60          1.00      -0.00       0.00       -0.00
#  4      92.0    99.0    95.29          0.99      -0.29       0.07       -0.01
#  ..      ...     ...      ...           ...        ...        ...         ...
#  459    80.0    82.0    81.00          0.99      -0.30      -0.24       -0.27
#  460    77.0    81.0    78.71          0.99      -0.28      -0.25       -0.26
#  461    78.0    84.0    81.20          0.99      -0.27      -0.26       -0.27
#  462    79.0    81.0    80.29          0.99      -0.27      -0.26       -0.27
#  463    80.0    81.0    80.17          0.99      -0.27      -0.26       -0.27
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.00      -0.99       -0.99       0.09       0.11        0.10
#  1        -1.00      -0.99       -0.99       0.09       0.11        0.10
#  2        -1.00      -0.99       -0.99       0.09       0.10        0.10
#  3        -1.00      -0.99       -0.99       0.09       0.11        0.10
#  4        -1.20      -0.28       -0.98      -0.38       0.36        0.11
#  ..         ...        ...         ...        ...        ...         ...
#  459       0.10       0.22        0.13      -0.96      -0.89       -0.94
#  460       0.10       0.16        0.12      -0.96      -0.92       -0.95
#  461       0.12       0.13        0.12      -0.95      -0.94       -0.95
#  462       0.12       0.13        0.12      -0.95      -0.94       -0.95
#  463       0.11       0.13        0.12      -0.95      -0.94       -0.95
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  13
#  1                     0                     0  13
#  2                     0                     0  13
#  3                     0                     0  13
#  4                     0                     0  13
#  ..                  ...                   ...  ..
#  459                   1                     2  13
#  460                   1                     2  13
#  461                   1                     2  13
#  462                   1                     2  13
#  463                   1                     2  13
#
#  [464 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        62      65    63.20          1.00      -0.34      -0.33       -0.34
#  1        64      69    66.50          1.00      -0.34      -0.33       -0.33
#  2        69      69    69.00          1.06      -0.84       0.83       -0.34
#  3        69      72    70.00          0.99      -0.77       1.01       -0.36
#  4        72      74    73.00          1.03      -0.63       0.09       -0.38
#  ..      ...     ...      ...           ...        ...        ...         ...
#  972      71      72    71.83          0.99      -0.32      -0.30       -0.31
#  973      69      72    70.33          0.99      -0.31      -0.30       -0.31
#  974      71      73    71.83          0.99      -0.31      -0.31       -0.31
#  975      72      73    72.40          0.99      -0.31      -0.31       -0.31
#  976      69      74    71.57          0.99      -0.31      -0.31       -0.31
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.79       0.80        0.80      -0.50      -0.49       -0.50
#  1         0.79       0.80        0.79      -0.51      -0.50       -0.50
#  2        -1.01       1.03        0.55      -1.87      -0.24       -0.63
#  3        -1.06       0.60       -0.09      -0.98       0.91       -0.47
#  4        -1.22      -0.07       -0.43      -1.30      -0.03       -0.75
#  ..         ...        ...         ...        ...        ...         ...
#  972       0.27       0.29        0.28      -0.90      -0.90       -0.90
#  973       0.27       0.29        0.28      -0.90      -0.90       -0.90
#  974       0.27       0.29        0.28      -0.91      -0.90       -0.90
#  975       0.27       0.29        0.28      -0.90      -0.90       -0.90
#  976       0.27       0.29        0.28      -0.91      -0.90       -0.90
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  14
#  1                     0                     0  14
#  2                     0                     0  14
#  3                     0                     0  14
#  4                     0                     0  14
#  ..                  ...                   ...  ..
#  972                   1                     2  14
#  973                   1                     2  14
#  974                   1                     2  14
#  975                   1                     2  14
#  976                   1                     2  14
#
#  [977 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        63      64    63.33          1.00      -0.49      -0.40       -0.48
#  1        64      65    64.57          1.00      -0.49      -0.48       -0.48
#  2        64      67    66.00          1.00      -0.52      -0.48       -0.50
#  3        55      65    59.83          1.00      -0.52      -0.41       -0.50
#  4        68      71    68.50          1.01      -0.59      -0.14       -0.46
#  ..      ...     ...      ...           ...        ...        ...         ...
#  753      72      76    73.17          1.00      -0.38      -0.37       -0.38
#  754      68      72    69.50          1.00      -0.38      -0.37       -0.38
#  755      69      74    72.00          1.00      -0.38      -0.37       -0.38
#  756      68      77    71.17          1.00      -0.43      -0.36       -0.38
#  757      77      95    87.83          1.01      -0.61      -0.27       -0.37
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.31       0.01       -0.02      -0.94      -0.74       -0.88
#  1        -0.02      -0.01       -0.02      -0.89      -0.87       -0.88
#  2        -0.03      -0.00       -0.01      -0.88      -0.86       -0.87
#  3        -0.07       0.04       -0.00      -0.93      -0.85       -0.87
#  4        -0.39       0.58        0.04      -1.02      -0.67       -0.88
#  ..         ...        ...         ...        ...        ...         ...
#  753      -0.16      -0.13       -0.15      -0.93      -0.91       -0.92
#  754      -0.16      -0.13       -0.15      -0.93      -0.91       -0.92
#  755      -0.16      -0.13       -0.15      -0.93      -0.91       -0.92
#  756      -0.16      -0.08       -0.14      -0.94      -0.89       -0.92
#  757      -0.34       0.43       -0.08      -1.33      -0.62       -0.92
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  15
#  1                     0                     0  15
#  2                     0                     0  15
#  3                     0                     0  15
#  4                     0                     0  15
#  ..                  ...                   ...  ..
#  753                   0                     5  15
#  754                   0                     0  15
#  755                   0                     0  15
#  756                   0                     0  15
#  757                   0                     0  15
#
#  [758 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        67      68    67.17          0.99      -0.92      -0.13       -0.46
#  1        59      66    61.67          1.00      -0.95      -0.44       -0.74
#  2        59      60    59.17          1.00      -0.50      -0.48       -0.49
#  3        59      59    59.00          1.00      -0.51      -0.48       -0.49
#  4        59      61    59.67          1.00      -0.49      -0.48       -0.49
#  ..      ...     ...      ...           ...        ...        ...         ...
#  956      59      71    66.80          1.00      -0.39      -0.38       -0.39
#  957      57      67    63.17          1.00      -0.39      -0.38       -0.39
#  958      67      83    70.40          1.00      -0.39      -0.36       -0.37
#  959      55      67    59.50          1.00      -0.37      -0.37       -0.37
#  960      50      62    58.40          1.00      -0.38      -0.36       -0.37
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.04       0.23       -0.18      -0.90       0.19       -0.80
#  1        -0.95       0.03       -0.52      -1.00       0.25       -0.15
#  2        -0.86      -0.84       -0.85       0.16       0.18        0.18
#  3        -0.86      -0.83       -0.85       0.16       0.21        0.19
#  4        -0.85      -0.84       -0.85       0.19       0.20        0.19
#  ..         ...        ...         ...        ...        ...         ...
#  956      -0.49      -0.48       -0.48       0.79       0.79        0.79
#  957      -0.49      -0.48       -0.48       0.78       0.79        0.79
#  958      -0.50      -0.46       -0.49       0.78       0.81        0.79
#  959      -0.50      -0.49       -0.50       0.78       0.79        0.79
#  960      -0.50      -0.49       -0.49       0.78       0.79        0.79
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  16
#  1                     0                     0  16
#  2                     0                     0  16
#  3                     0                     0  16
#  4                     0                     0  16
#  ..                  ...                   ...  ..
#  956                   0                     5  16
#  957                   0                     5  16
#  958                   0                     5  16
#  959                   0                     5  16
#  960                   0                     5  16
#
#  [961 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        79      86    81.17          1.01      -0.63       1.13        0.70
#  1        81      82    81.83          1.04      -0.55       1.25        0.30
#  2        83      86    85.00          1.02      -1.32       0.04       -0.43
#  3        71      85    78.57          1.00      -0.61       0.05       -0.15
#  4        68      69    68.80          1.00      -1.04      -0.11       -0.60
#  ..      ...     ...      ...           ...        ...        ...         ...
#  976      57      60    59.00          1.00      -0.18      -0.17       -0.17
#  977      57      61    59.17          1.00      -0.18      -0.17       -0.17
#  978      60      62    60.80          1.00      -0.18      -0.17       -0.17
#  979      61      64    63.17          1.00      -0.18      -0.17       -0.17
#  980      62      70    64.67          1.01      -0.46      -0.02       -0.16
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.33       1.13        0.42      -1.00       0.92       -0.02
#  1        -0.49       1.54        0.56      -1.74       1.39       -0.18
#  2        -1.06       1.01        0.32      -1.25       1.29       -0.53
#  3         0.11       1.39        0.50      -1.62      -0.60       -0.85
#  4        -0.01       1.28        0.44      -0.85       0.34       -0.34
#  ..         ...        ...         ...        ...        ...         ...
#  976      -0.15      -0.13       -0.14       0.97       0.98        0.98
#  977      -0.14      -0.13       -0.13       0.97       0.98        0.98
#  978      -0.14      -0.13       -0.13       0.98       0.99        0.98
#  979      -0.14      -0.13       -0.13       0.98       0.99        0.98
#  980      -0.14       1.38        0.13      -0.72       1.35        0.90
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  17
#  1                     0                     0  17
#  2                     0                     0  17
#  3                     0                     0  17
#  4                     0                     0  17
#  ..                  ...                   ...  ..
#  976                   1                     2  17
#  977                   1                     2  17
#  978                   1                     2  17
#  979                   1                     2  17
#  980                   0                     0  17
#
#  [981 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      70.0    75.0    72.20          1.00      -0.81       0.51       -0.03
#  1      71.0    77.0    74.43          0.99      -0.00       0.28        0.08
#  2      62.0    67.0    63.83          0.99       0.06       0.09        0.08
#  3      61.0    63.0    62.17          0.99       0.07       0.08        0.08
#  4      62.0    67.0    64.50          0.99      -0.29       0.14       -0.01
#  ..      ...     ...      ...           ...        ...        ...         ...
#  469    58.0    70.0    63.80          0.99      -0.55      -0.00       -0.21
#  470    66.0    79.0    72.67          0.99      -1.02      -0.05       -0.19
#  471    66.0    73.0    68.83          1.00      -0.13      -0.12       -0.12
#  472    59.0    61.0    60.33          1.00      -0.13      -0.12       -0.13
#  473    56.0    60.0    57.67          1.00      -0.13      -0.12       -0.12
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.11       1.18        0.29      -1.19       0.17       -0.78
#  1        -0.61       0.56        0.34      -1.18      -0.73       -0.92
#  2         0.25       0.27        0.26      -0.96      -0.95       -0.96
#  3         0.26       0.26        0.26      -0.96      -0.95       -0.96
#  4         0.06       1.09        0.49      -0.96       1.03       -0.40
#  ..         ...        ...         ...        ...        ...         ...
#  469       0.18       1.10        0.67      -1.06      -0.13       -0.61
#  470      -1.03       1.16       -0.65      -0.50       0.61       -0.17
#  471      -0.97      -0.96       -0.97      -0.21      -0.20       -0.20
#  472      -0.97      -0.95       -0.97      -0.21      -0.20       -0.20
#  473      -0.97      -0.96       -0.97      -0.21      -0.20       -0.21
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  18
#  1                     0                     0  18
# ...
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  24
#  1                     0                     0  24
#  2                     0                     0  24
#  3                     0                     0  24
#  4                     0                     0  24
#  ..                  ...                   ...  ..
#  943                   0                     0  24
#  944                   0                     0  24
#  945                   0                     0  24
#  946                   0                     0  24
#  947                   0                     0  24
#
#  [948 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        58      60    58.67          0.99      -0.45      -0.29       -0.40
#  1        60      61    60.40          0.99      -0.73      -0.03       -0.41
#  2        64      70    67.83          0.99      -0.92      -0.35       -0.41
#  3        63      68    64.40          1.02      -1.80       0.34       -0.65
#  4        60      61    60.17          1.00      -0.97      -0.19       -0.53
#  ..      ...     ...      ...           ...        ...        ...         ...
#  960      59      83    63.00          1.01       0.00       0.02        0.01
#  961      58      60    58.50          1.01      -0.05       0.20        0.01
#  962      60      74    70.17          1.01       0.01       0.03        0.02
#  963      59      72    68.80          1.01       0.01       0.02        0.01
#  964      56      58    57.00          1.01       0.01       0.01        0.01
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.15       0.31        0.04      -1.09      -0.87       -0.91
#  1        -0.21       0.75        0.23      -1.11      -0.30       -0.82
#  2        -0.07       0.46        0.10      -1.14      -0.32       -0.89
#  3        -1.43       0.95       -0.10      -1.66      -0.07       -0.60
#  4        -0.50       0.79        0.04      -1.38       0.02       -0.71
#  ..         ...        ...         ...        ...        ...         ...
#  960      -0.21      -0.20       -0.20       0.98       0.99        0.99
#  961      -0.34      -0.06       -0.21       0.91       1.09        0.98
#  962      -0.22      -0.19       -0.20       0.98       1.00        0.99
#  963      -0.20      -0.18       -0.19       0.98       0.99        0.99
#  964      -0.19      -0.18       -0.18       0.98       0.99        0.99
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  25
#  1                     0                     0  25
#  2                     0                     0  25
#  3                     0                     0  25
#  4                     0                     0  25
#  ..                  ...                   ...  ..
#  960                   1                     1  25
#  961                   0                     0  25
#  962                   1                     1  25
#  963                   1                     1  25
#  964                   0                     0  25
#
#  [965 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        73      77    75.00           1.0      -0.02      -0.01       -0.01
#  1        76      77    76.50           1.0      -0.05       0.11       -0.02
#  2        72      76    73.80           1.0      -0.03      -0.02       -0.03
#  3        72      75    73.67           1.0      -0.03      -0.02       -0.02
#  4        75      77    76.00           1.0      -0.02      -0.01       -0.02
#  ..      ...     ...      ...           ...        ...        ...         ...
#  965      72      74    73.00           1.0      -0.22      -0.21       -0.22
#  966      71      74    72.50           1.0      -0.22      -0.21       -0.22
#  967      69      73    71.00           1.0      -0.22      -0.21       -0.22
#  968      70      76    73.17           1.0      -0.22      -0.21       -0.22
#  969      68      75    72.20           1.0      -0.22      -0.21       -0.22
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.72       0.73        0.72      -0.69      -0.68       -0.68
#  1         0.11       0.72        0.62      -0.97      -0.68       -0.77
#  2         0.58       0.59        0.58      -0.81      -0.80       -0.81
#  3         0.58       0.59        0.58      -0.82      -0.80       -0.81
#  4         0.58       0.59        0.58      -0.82      -0.80       -0.81
#  ..         ...        ...         ...        ...        ...         ...
#  965       0.73       0.74        0.73      -0.64      -0.63       -0.64
#  966       0.73       0.74        0.73      -0.64      -0.63       -0.64
#  967       0.73       0.74        0.73      -0.64      -0.63       -0.64
#  968       0.73       0.74        0.73      -0.64      -0.63       -0.64
#  969       0.73       0.74        0.73      -0.64      -0.63       -0.64
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  26
#  1                     0                     0  26
#  2                     0                     0  26
#  3                     0                     0  26
#  4                     0                     0  26
#  ..                  ...                   ...  ..
#  965                   1                     2  26
#  966                   1                     2  26
#  967                   1                     2  26
#  968                   1                     2  26
#  969                   0                     0  26
#
#  [970 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        68      69    68.14          1.00      -0.76      -0.33       -0.48
#  1        68      69    68.20          1.00      -0.84       0.27       -0.48
#  2        70      72    70.50          0.99      -0.99      -0.37       -0.43
#  3        68      69    68.83          0.99      -0.62      -0.38       -0.39
#  4        68      69    68.80          0.99      -0.39      -0.38       -0.38
#  ..      ...     ...      ...           ...        ...        ...         ...
#  959      64      66    65.50          1.00       0.15       0.17        0.16
#  960      63      66    64.60          1.00       0.15       0.16        0.16
#  961      63      67    65.00          1.00       0.15       0.16        0.16
#  962      63      63    63.00          1.00       0.15       0.16        0.16
#  963      63      64    63.33          1.00       0.15       0.16        0.16
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.52       0.90        0.42      -1.42       0.53       -0.66
#  1        -0.50       0.94        0.26      -1.43       0.10       -0.81
#  2        -0.02       0.60        0.27      -0.92      -0.13       -0.84
#  3         0.22       0.85        0.25      -0.89      -0.18       -0.88
#  4         0.25       0.27        0.26      -0.89      -0.88       -0.88
#  ..         ...        ...         ...        ...        ...         ...
#  959      -0.24      -0.22       -0.23      -0.97      -0.95       -0.96
#  960      -0.23      -0.22       -0.23      -0.96      -0.95       -0.96
#  961      -0.24      -0.22       -0.23      -0.96      -0.95       -0.96
#  962      -0.23      -0.22       -0.23      -0.96      -0.95       -0.96
#  963      -0.24      -0.22       -0.23      -0.96      -0.95       -0.96
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  27
#  1                     0                     0  27
#  2                     0                     0  27
#  3                     0                     0  27
#  4                     0                     0  27
#  ..                  ...                   ...  ..
#  959                   0                     5  27
#  960                   0                     5  27
#  961                   0                     5  27
#  962                   0                     5  27
#  963                   0                     5  27
#
#  [964 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      76.0    77.0    76.50          1.01      -0.63      -0.36       -0.50
#  1      74.0    76.0    75.17          1.00      -0.54      -0.43       -0.50
#  2      76.0    77.0    76.67          1.00      -0.51      -0.42       -0.49
#  3      71.0    74.0    72.33          1.01      -0.49      -0.48       -0.48
#  4      70.0    72.0    71.40          1.01      -0.49      -0.48       -0.48
#  ..      ...     ...      ...           ...        ...        ...         ...
#  969    69.0    71.0    69.33          1.00      -0.48      -0.46       -0.46
#  970    68.0    75.0    69.33          1.00      -0.47      -0.46       -0.46
#  971    70.0    77.0    73.33          1.00      -0.46      -0.46       -0.46
#  972    69.0    71.0    70.20          1.00      -0.46      -0.45       -0.46
#  973    66.0    68.0    67.17          1.00      -0.46      -0.46       -0.46
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.49       1.06        0.45      -0.89       0.21       -0.63
#  1        -0.31       0.41        0.24      -0.95      -0.72       -0.82
#  2         0.02       0.98        0.43      -0.87      -0.19       -0.64
#  3         0.77       0.78        0.78      -0.43      -0.41       -0.42
#  4         0.76       0.78        0.78      -0.43      -0.41       -0.42
#  ..         ...        ...         ...        ...        ...         ...
#  969       0.05       0.15        0.06      -0.91      -0.88       -0.89
#  970       0.06       0.07        0.06      -0.89      -0.88       -0.89
#  971       0.05       0.06        0.06      -0.90      -0.88       -0.89
#  972       0.05       0.07        0.06      -0.90      -0.88       -0.89
#  973       0.04       0.07        0.06      -0.90      -0.88       -0.89
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  28
#  1                     0                     0  28
#  2                     0                     0  28
#  3                     0                     0  28
#  4                     0                     0  28
#  ..                  ...                   ...  ..
#  969                   0                     0  28
#  970                   1                     1  28
#  971                   0                     0  28
#  972                   1                     2  28
#  973                   1                     2  28
#
#  [974 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      55.0    59.0    57.40          0.99      -0.44      -0.43       -0.44
#  1      56.0    59.0    57.86          0.99      -0.44      -0.43       -0.44
#  2      57.0    57.0    57.00          0.99      -0.44      -0.42       -0.43
#  3      58.0    67.0    62.83          1.00      -0.81      -0.37       -0.40
#  4      59.0    61.0    59.60          1.01      -0.98       1.09       -0.31
#  ..      ...     ...      ...           ...        ...        ...         ...
#  939    61.0    63.0    61.80          1.00       0.57       0.58        0.57
#  940    62.0    63.0    62.50          1.00       0.57       0.58        0.57
#  941    61.0    63.0    62.17          1.00       0.57       0.58        0.57
#  942    62.0    62.0    62.00          1.00       0.57       0.58        0.57
#  943    58.0    65.0    63.40          1.00       0.57       0.58        0.57
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.39       0.41        0.40      -0.80      -0.79       -0.79
#  1         0.39       0.41        0.40      -0.80      -0.78       -0.79
#  2         0.40       0.43        0.41      -0.80      -0.77       -0.79
#  3        -0.23       0.96        0.34      -1.13      -0.27       -0.84
#  4         0.00       1.48        0.69      -1.01       0.62       -0.20
#  ..         ...        ...         ...        ...        ...         ...
#  939       0.72       0.73        0.72      -0.39      -0.37       -0.38
#  940       0.72       0.73        0.72      -0.39      -0.37       -0.38
#  941       0.72       0.73        0.72      -0.39      -0.37       -0.38
#  942       0.72       0.73        0.72      -0.39      -0.38       -0.38
#  943       0.72       0.74        0.73      -0.39      -0.36       -0.38
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  29
#  1                     0                     0  29
#  2                     0                     0  29
#  3                     0                     0  29
#  4                     0                     0  29
#  ..                  ...                   ...  ..
#  939                   1                     2  29
#  940                   1                     2  29
#  941                   1                     2  29
#  942                   1                     2  29
#  943                   1                     2  29
#
#  [944 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      50.0    55.0    51.40          0.99      -0.34      -0.30       -0.32
#  1      51.0    58.0    54.86          1.01      -1.15       0.46       -0.32
#  2      56.0    68.0    61.60          1.00      -0.70       0.23       -0.29
#  3      51.0    56.0    53.17          0.99      -0.31      -0.28       -0.30
#  4      48.0    51.0    49.43          0.99      -0.32      -0.28       -0.30
#  ..      ...     ...      ...           ...        ...        ...         ...
#  714    68.0    78.0    70.17          0.99      -0.57       0.12       -0.31
#  715    69.0    69.0    69.00          0.99      -0.27      -0.25       -0.26
#  716    65.0    68.0    65.60          0.99      -0.27      -0.25       -0.26
#  717    68.0    71.0    70.17          1.05      -0.53       1.78        0.29
#  718    74.0    80.0    76.00          1.00      -1.27       0.90       -0.16
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.26       0.35        0.29      -0.91      -0.89       -0.89
#  1        -1.20       1.31       -0.04      -1.24       1.06       -0.57
#  2        -0.55       0.18       -0.14      -1.17      -0.71       -0.94
#  3        -0.13      -0.11       -0.12      -0.95      -0.92       -0.94
#  4        -0.14      -0.11       -0.12      -0.96      -0.92       -0.94
#  ..         ...        ...         ...        ...        ...         ...
#  714      -0.80       1.14        0.13      -1.26      -0.47       -0.91
#  715       0.24       0.27        0.25      -0.93      -0.91       -0.92
#  716       0.23       0.26        0.25      -0.93      -0.91       -0.92
#  717      -0.93       1.69        0.07      -1.43       0.18       -0.62
#  718      -1.64       1.10       -0.24      -1.25       0.85       -0.62
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  30
#  1                     0                     0  30
#  2                     0                     0  30
#  3                     0                     0  30
#  4                     0                     0  30
#  ..                  ...                   ...  ..
#  714                   0                     0  30
#  715                   0                     0  30
#  716                   0                     0  30
#  717                   0                     0  30
#  718                   0                     0  30
#
#  [719 rows x 16 columns]]

# %% [markdown]
# Como hay algunos valores NaN, se utiliza la siguiente funcion para **limpiar el dataframe** de NaN y valores infinitos:

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    
    return df[indices_to_keep].astype(np.float64)

# %%
clean_df = clean_dataset(pd.concat(df))

# %%
clean_df.describe()
# Out:
#              Min_hr        Max_hr       Mean_hr  Men_acc_sqrt     Min_acc_x  \
# count  25891.000000  25891.000000  25891.000000  25891.000000  25891.000000
# mean      62.689815     66.180835     64.336429      0.997785     -0.156519
# std        9.713672     10.873633     10.071484      0.005416      0.376134
# min       41.000000     42.000000     41.170000      0.980000     -3.890000
# 25%       55.000000     59.000000     57.000000      0.990000     -0.420000
# 50%       62.000000     66.000000     64.000000      1.000000     -0.240000
# 75%       68.000000     73.000000     70.500000      1.000000      0.080000
# max      127.000000    130.000000    128.570000      1.110000      0.830000
#
#           Max_acc_x    Mean_acc_x     Min_acc_y     Max_acc_y    Mean_acc_y  \
# count  25891.000000  25891.000000  25891.000000  25891.000000  25891.000000
# mean      -0.094177     -0.124166     -0.137101     -0.042957     -0.088632
# std        0.374470      0.354902      0.490221      0.500200      0.468462
# min       -0.950000     -0.980000     -2.780000     -1.000000     -1.000000
# 25%       -0.360000     -0.380000     -0.490000     -0.400000     -0.430000
# 50%       -0.180000     -0.210000     -0.130000     -0.030000     -0.070000
# 75%        0.150000      0.100000      0.200000      0.270000      0.220000
# max        3.250000      0.850000      0.990000      4.220000      0.990000
#
#           Min_acc_z     Max_acc_z    Mean_acc_z  Etiquetas binarias  \
# count  25891.000000  25891.000000  25891.000000        25891.000000
# mean      -0.495783     -0.412916     -0.458539            0.687189
# std        0.644017      0.659544      0.636868            0.463647
# min       -3.380000     -1.000000     -1.000000            0.000000
# 25%       -0.920000     -0.890000     -0.900000            0.000000
# 50%       -0.820000     -0.780000     -0.800000            1.000000
# 75%       -0.240000      0.010000     -0.125000            1.000000
# max        1.000000      3.870000      1.010000            1.000000
#
#        Etiquetas multiclase            ID
# count          25891.000000  25891.000000
# mean               2.514078     15.148739
# std                1.504283      9.213845
# min                0.000000      0.000000
# 25%                2.000000      7.000000
# 50%                2.000000     15.000000
# 75%                3.000000     23.000000
# max                5.000000     30.000000

# %% [markdown]
# Se guarda en un dataframe el conjunto de características extraídas:

# %%
clean_df.to_csv('features.csv', header=True, index=False)

# %% [markdown]
# ### 3. Visualización datos dataframe

# %%
rows, columns = clean_df.shape #Forma de la BD
print ('La base de datos tiene', rows,'filas y',columns,'columnas\n')

print('Número de valores diferentes que hay para cada atributo:')
print(clean_df.nunique(),'\n')

print('Número de valores Null:')
print(clean_df.isnull().sum(),'\n')

print('Número de valores NaN:')
print(clean_df.isna().sum(),'\n')

print('Descriptores estadísticos:')
print(clean_df.describe().round(2),'\n')
# Out:
# La base de datos tiene 25891 filas y 16 columnas
#
# Número de valores diferentes que hay para cada atributo:
# Min_hr                   72
# Max_hr                   80
# Mean_hr                 919
# Men_acc_sqrt             11
# Min_acc_x               235
# Max_acc_x               248
# Mean_acc_x              178
# Min_acc_y               276
# Max_acc_y               286
# Mean_acc_y              200
# Min_acc_z               306
# Max_acc_z               249
# Mean_acc_z              202
# Etiquetas binarias        2
# Etiquetas multiclase      5
# ID                       31
# dtype: int64
#
# Número de valores Null:
# Min_hr                  0
# Max_hr                  0
# Mean_hr                 0
# Men_acc_sqrt            0
# Min_acc_x               0
# Max_acc_x               0
# Mean_acc_x              0
# Min_acc_y               0
# Max_acc_y               0
# Mean_acc_y              0
# Min_acc_z               0
# Max_acc_z               0
# Mean_acc_z              0
# Etiquetas binarias      0
# Etiquetas multiclase    0
# ID                      0
# dtype: int64
#
# Número de valores NaN:
# Min_hr                  0
# Max_hr                  0
# Mean_hr                 0
# Men_acc_sqrt            0
# Min_acc_x               0
# Max_acc_x               0
# Mean_acc_x              0
# Min_acc_y               0
# Max_acc_y               0
# Mean_acc_y              0
# Min_acc_z               0
# Max_acc_z               0
# Mean_acc_z              0
# Etiquetas binarias      0
# Etiquetas multiclase    0
# ID                      0
# dtype: int64
#
# Descriptores estadísticos:
#          Min_hr    Max_hr   Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  \
# count  25891.00  25891.00  25891.00      25891.00   25891.00   25891.00
# mean      62.69     66.18     64.34          1.00      -0.16      -0.09
# std        9.71     10.87     10.07          0.01       0.38       0.37
# min       41.00     42.00     41.17          0.98      -3.89      -0.95
# 25%       55.00     59.00     57.00          0.99      -0.42      -0.36
# 50%       62.00     66.00     64.00          1.00      -0.24      -0.18
# 75%       68.00     73.00     70.50          1.00       0.08       0.15
# max      127.00    130.00    128.57          1.11       0.83       3.25
#
#        Mean_acc_x  Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  \
# count    25891.00   25891.00   25891.00    25891.00   25891.00   25891.00
# mean        -0.12      -0.14      -0.04       -0.09      -0.50      -0.41
# std          0.35       0.49       0.50        0.47       0.64       0.66
# min         -0.98      -2.78      -1.00       -1.00      -3.38      -1.00
# 25%         -0.38      -0.49      -0.40       -0.43      -0.92      -0.89
# 50%         -0.21      -0.13      -0.03       -0.07      -0.82      -0.78
# 75%          0.10       0.20       0.27        0.22      -0.24       0.01
# max          0.85       0.99       4.22        0.99       1.00       3.87
#
#        Mean_acc_z  Etiquetas binarias  Etiquetas multiclase        ID
# count    25891.00            25891.00              25891.00  25891.00
# mean        -0.46                0.69                  2.51     15.15
# std          0.64                0.46                  1.50      9.21
# min         -1.00                0.00                  0.00      0.00
# 25%         -0.90                0.00                  2.00      7.00
# 50%         -0.80                1.00                  2.00     15.00
# 75%         -0.12                1.00                  3.00     23.00
# max          1.01                1.00                  5.00     30.00

# %% [markdown]
# **DIAGRAMA DE DISPERSIÓN**
#
# En el siguiente gráfico se puede ver, en la diagonal, el histograma de cada par de variables.
#
# El resto son diagramas de dispersión. La finalidad de estos es buscar si existe relación lineal o no lineal entre algún par de variables.

# %%
disper = sns.PairGrid(clean_df)
disper = disper.map_diag(plt.hist, alpha=0.7)
disper = disper.map_offdiag(plt.scatter, marker='.')

# %% [markdown]
# **MAPA DE CALOR**
#
# Diagrama que nos devuelve la relación lineal entre las variables.

# %%
f, ax = plt.subplots(figsize=(15,15))
corr = clean_df.corr()
#sns.heatmap(corr)
sns.heatmap(corr, annot=True, cmap="YlGnBu", xticklabels=corr.columns.values, yticklabels=corr.columns.values,square=True)

# %% [markdown]
# **DISTRIBUCCIÓN DE LAS ETIQUETAS EN EL CONJUNTO DE DATOS**

# %%
clean_df['Etiquetas binarias'].value_counts().plot.bar(title="BALANCEO DE CLASES BINARIAS")
plt.figure()
print(clean_df["Etiquetas binarias"].value_counts() )

plt.figure()
clean_df['Etiquetas multiclase'].value_counts().plot.bar(title="BALANCEO DE CLASES MULTICLASE")
print(clean_df["Etiquetas multiclase"].value_counts() )
# Out:
# 1.0    17792
# 0.0     8099
# Name: Etiquetas binarias, dtype: int64
# 2.0    12485
# 5.0     5545
# 3.0     3545
# 0.0     2554
# 1.0     1762
# Name: Etiquetas multiclase, dtype: int64
