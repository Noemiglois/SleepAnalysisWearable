# %% [markdown]
# <center> <h1>PREDICCIÓN DEL SUEÑO</h1> </center>
# <center> <h3>CREACIÓN DEL DATAFRAME PARALELIZANDO</h3> </center>
# <center> <h4>Noemi González, Roberto Holgado y Carmen Plaza</h4> </center>
#
# ### Índice de contenidos de este Notebook
#
# En este Notebook se realiza el preprocesado de las 3 características: frecuencia cardíaca, aceleración y pasos. Se extraen características a partir de ellas y se almacenan en un dataframe 'features' que contiene las características de los 31 sujetos. Para ello se siguen los siguientes pasos:
#
#     1. Creación ventana deslizante
#     2. Extracción de características y obtención dataframe
#         2.1. Paralelizar construcción de la matriz de características
#     3. Visualización datos dataframe

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from random import sample
import statistics as stats
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from multiprocessing import Pool
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# Se cargan los datos de las distintas carpetas en listas:

# %%
# LISTAS CON LOS NOMBRES DE TODOS LOS ARCHIVOS .txt
sujetos_sueño=[]
for file in (os.listdir("labels")):
    sujetos_sueño.append(os.path.join("labels",file))
    sujetos_sueño=sorted(sujetos_sueño)
    
sujetos_frec_card=[]
for file in os.listdir("heart_rate"):
    sujetos_frec_card.append(os.path.join("heart_rate",file))

sujetos_pasos=[]
for file in os.listdir("steps"):
    sujetos_pasos.append(os.path.join("steps",file))

sujetos_movimiento=[]
for file in os.listdir("motion"):
    sujetos_movimiento.append(os.path.join("motion",file))

# %% [markdown]
# ### 1. Creación ventana deslizante

# %% [markdown]
# La ventana deslizante recorre la señal fisiológica introducida como parámetro de entrada (*signal*). La función *'get_window'*, además, toma como datos de entrada el tamaño de la ventana en segundos (*w_size*) y la longitud de la señal de las etiquetas del sueño (*n_sueño*).
#
# Esta función recorre el eje de tiempo de la señal deseada y va asignando índices (True o False) según se cumpla o no el parámetro establecido en el segundo bucle for. Dicha condición depende directamente del tamaño de ventana que se seleccione.
# * Si el eje de tiempo está entre los valores 'a' y 'b' se asiga True
# * Si esa condición no se cumplese asigna False

# %%
def get_window(w_size,signal,n_sueño):
    time = signal["Tiempo"]
    f_list=[]
    
    for i in range(n_sueño):
        a = w_size*(1+i)
        b = w_size*(2+i)

        idx=[]
        for t in time:
            if t>a and t<b:
                idx.append(True)
            else:
                idx.append(False)
        
        f = signal[idx]
        f_list.append(f)
    
    return f_list

# %% [markdown]
# En esta ocasión se selecciona una *w_size*=**30 segundos**, para tener una característica cada 30s y así hacer coincidir la cantidad de los datos adquiridos por medio del Apple Watch con los datos recogidos por la PSG.

# %% [markdown]
# ### 2. Extracción de características y obtención del dataframe

# %% [markdown]
# A continuación se detallan las características extraídas con la ventana deslizante a partir de las originales:
#
# * **feat1: min_list**: frecuencias cardíacas mínimas.
# * **feat2: max_list**: frecuencias cardíacas máximas.
# * **feat3: mean_list**: frecuencias cardíacas medias.
#
# * **feat4: mean_sqrt_acc**: aceleraciones medias.
#
# * **feat5: min_accx**: aceleraciones eje x mínimas.
# * **feat6: max_accx**: aceleraciones eje x máximas.
# * **feat7: mean_accx**: aceleraciones eje x medias.
#
# * **feat8: min_accy**: aceleraciones eje y mínimas.
# * **feat9: max_accy**: aceleraciones eje y máximas.
# * **feat10: mean_accy**: aceleraciones eje y medias.
#
# * **feat11: min_accz**: aceleraciones eje z mínimas.
# * **feat12: max_accz**: aceleraciones eje z máximas.
# * **feat13: mean_accz**: aceleraciones eje z medias.
#
# Con todas las características se ha creado un dataframe que incluye a todos los sujetos. Además, se han añadido una columna con los **identificadores de cada sujeto** para tener los datos localizados en todo momento.
#
# La columna de **etiquetas binarias** es una modificación de la columna etiquetas. Se ha realizado esta modificación para crear un clasificador de salida binaria como primera aproximación.

# %% [markdown]
# #### 2.1. Paralelizar construcción de la matriz de características
#
# Se crea una función con el bucle que construye la matriz de características. De esta forma, se puede paralelizar su obtención con la herramienta 'multiproccesing', en concreto con la función 'Pool'.

# %%
def dataframe(sujetos_sueño,sujetos_frec_card,sujetos_pasos,sujetos_movimiento):
    
    df = []

    for a, (i,j,k,l) in  enumerate(zip(sujetos_sueño,sujetos_frec_card,sujetos_pasos,sujetos_movimiento)):
        w_size = 30


        #SUEÑO
        sueño = pd.read_csv(i, delimiter=' ')
        sueño.columns = ["Tiempo","Etiqueta"]
        n_sueño = len(sueño)

        #SUEÑO BINARIO
        sueño_bin = sueño.replace(to_replace =[-1,5],  value =0) 
        sueño_bin = sueño_bin.replace(to_replace =[2,3,4],  value =1) #Etiquetas binarias 0-sueño ligero 1-sueño profundo
        bin_labels = sueño_bin["Etiqueta"]

        #SUEÑO MULTICLASE
        sueño_multi = sueño.replace(to_replace =[-1],  value =0) 
        sueño_multi = sueño_multi.replace(to_replace =[4],  value =3) #Etiquetas multiclase 0-sueño muy ligero
                                                                        #1,2,3-sueño profundo 5-sueño ligero(rem)
        multi_labels = sueño_multi["Etiqueta"]

        #ID_LIST
        labels = sueño["Etiqueta"]
        id_list = [a]*len(labels)

        #FRECUENCIA CARDIACA
        frec_card = pd.read_csv(j)
        frec_card.columns = ["Tiempo","Frec card"]
        frec_card=frec_card[frec_card["Tiempo"]>0]

        signal = frec_card
        f_list = get_window(w_size,signal,n_sueño)

        fc_mean_list = []
        fc_min_list = []
        fc_max_list = []

        for f in f_list:
            fc_mean_list.append(round(f['Frec card'].mean(),2))
            fc_min_list.append(round(f['Frec card'].min(),2))
            fc_max_list.append(round(f['Frec card'].max(),2))

        feat1 = fc_min_list
        feat2 = fc_max_list
        feat3 = fc_mean_list

        #ACCELERACION
        mov=pd.read_csv(l, delimiter=' ')
        mov.columns=["Tiempo","Ac_x","Ac_y","Ac_z"]
        mov_t=mov[mov['Tiempo']>0]

        mov_t=mov_t.sample(frac=.1)
        mov_t=mov_t.sort_values('Tiempo')
        raiz_movto= np.sqrt(mov_t.Ac_x**2 + mov_t.Ac_y**2 + mov_t.Ac_z**2)
        mov_t['Raiz_movto'] = raiz_movto

        signal=mov_t
        acc_list= get_window(w_size,signal,n_sueño)

        mean_sqrt_acc=[]

        min_accx=[]
        max_accx=[]
        mean_accx=[]

        min_accy=[]
        max_accy=[]
        mean_accy=[]

        min_accz=[]
        max_accz=[]
        mean_accz=[]

        for f in acc_list:
            mean_sqrt_acc.append(round(f['Raiz_movto'].mean(),2))

            min_accx.append(round(f['Ac_x'].min(),2))
            max_accx.append(round(f['Ac_x'].max(),2))
            mean_accx.append(round(f['Ac_x'].mean(),2))

            min_accy.append(round(f['Ac_y'].min(),2))
            max_accy.append(round(f['Ac_y'].max(),2))
            mean_accy.append(round(f['Ac_y'].mean(),2))

            min_accz.append(round(f['Ac_z'].min(),2))
            max_accz.append(round(f['Ac_z'].max(),2))
            mean_accz.append(round(f['Ac_z'].mean(),2))

        feat4=mean_sqrt_acc

        feat5=min_accx
        feat6=max_accx
        feat7=mean_accx

        feat8=min_accy
        feat9=max_accy
        feat10=mean_accy

        feat11=min_accz
        feat12=max_accz
        feat13=mean_accz

        datos = {'Min_hr': feat1, "Max_hr": feat2,"Mean_hr":feat3,'Men_acc_sqrt': feat4,
                 "Min_acc_x": feat5,"Max_acc_x":feat6,"Mean_acc_x": feat7,
                 "Min_acc_y": feat8,"Max_acc_y":feat9,"Mean_acc_y":feat10,
                 "Min_acc_z": feat11,"Max_acc_z":feat12,"Mean_acc_z":feat13,
                "Etiquetas binarias":bin_labels,"Etiquetas multiclase":multi_labels, "ID":id_list}

        datos_sujeto = pd.DataFrame(data=datos)
        df.append(datos_sujeto)
        
    return df

# %% [markdown]
# El siguiente código paraleliza la obtención de la matriz de características utilizando dos núcleos y la función 'Pool'. Esta función permite trabajar con grandes cantidades de datos.
#
# Tiempo de ejecución: 31 minutos

# %%
#start_time = time.time()

if __name__ == '__main__':
    p = Pool(processes=2) 
    df=p.apply(dataframe,(sujetos_sueño,sujetos_frec_card,sujetos_pasos,sujetos_movimiento))
    
#print ("My program took", time.time() - start_time, "to run")

# %%
print(len(df))
# Out:
# 31

# %%
df
# Out:
# [     Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        74      75    74.43           1.0      -0.02       0.11        0.06
#  1        64      73    68.17           1.0      -0.82       0.05       -0.41
#  2        63      66    63.83           1.0      -0.85       0.09       -0.37
#  3        68      68    68.00           1.0      -0.32       0.29        0.04
#  4        69      70    69.20           1.0      -0.76       0.92        0.21
#  ..      ...     ...      ...           ...        ...        ...         ...
#  946      62      67    65.00           1.0      -0.27      -0.26       -0.27
#  947      66      67    66.50           1.0      -0.27      -0.26       -0.27
#  948      60      65    62.00           1.0      -0.27      -0.26       -0.27
#  949      64      66    65.17           1.0      -0.27      -0.26       -0.27
#  950      66      75    72.83           1.0      -0.27      -0.26       -0.27
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.18       1.03        0.51      -1.02      -0.06       -0.83
#  1        -0.00       1.13        0.61      -1.00       0.05       -0.42
#  2         0.25       1.00        0.57      -0.97      -0.16       -0.52
#  3         0.30       0.99        0.71      -1.09      -0.19       -0.65
#  4        -0.01       1.05        0.58      -0.97       0.29       -0.55
#  ..         ...        ...         ...        ...        ...         ...
#  946      -0.53      -0.51       -0.52      -0.83      -0.81       -0.82
#  947      -0.52      -0.51       -0.52      -0.82      -0.81       -0.82
#  948      -0.52      -0.51       -0.52      -0.82      -0.81       -0.82
#  949      -0.52      -0.51       -0.52      -0.82      -0.81       -0.82
#  950      -0.52      -0.51       -0.52      -0.82      -0.81       -0.82
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   0
#  1                     0                     0   0
#  2                     0                     0   0
#  3                     0                     0   0
#  4                     0                     0   0
#  ..                  ...                   ...  ..
#  946                   0                     0   0
#  947                   0                     0   0
#  948                   0                     0   0
#  949                   0                     0   0
#  950                   0                     0   0
#
#  [951 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        79      86    81.17          1.01      -0.60      -0.37       -0.50
#  1        81      82    81.83          1.00      -0.53      -0.39       -0.50
#  2        83      86    85.00          1.01      -0.54      -0.42       -0.49
#  3        71      85    78.57          1.01      -0.49      -0.48       -0.48
#  4        68      69    68.80          1.01      -0.49      -0.48       -0.48
#  ..      ...     ...      ...           ...        ...        ...         ...
#  962      58      61    59.20          1.00      -0.47      -0.47       -0.47
#  963      61      90    69.67          1.00      -0.47      -0.46       -0.47
#  964      56      90    62.50          1.00      -0.47      -0.46       -0.47
#  965      55      55    55.00          1.00      -0.47      -0.46       -0.47
#  966      55      57    56.33          1.00      -0.47      -0.46       -0.47
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.20       0.98        0.39      -0.91       0.09       -0.70
#  1        -0.27       0.44        0.26      -1.00      -0.37       -0.82
#  2         0.03       1.06        0.53      -0.88      -0.13       -0.58
#  3         0.77       0.78        0.78      -0.43      -0.42       -0.42
#  4         0.77       0.78        0.78      -0.44      -0.41       -0.42
#  ..         ...        ...         ...        ...        ...         ...
#  962       0.04       0.05        0.05      -0.89      -0.88       -0.88
#  963       0.04       0.05        0.05      -0.89      -0.88       -0.88
#  964       0.04       0.05        0.05      -0.89      -0.88       -0.88
#  965       0.04       0.05        0.05      -0.89      -0.88       -0.88
#  966       0.04       0.05        0.05      -0.89      -0.88       -0.89
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   1
#  1                     0                     0   1
#  2                     0                     0   1
#  3                     0                     0   1
#  4                     0                     0   1
#  ..                  ...                   ...  ..
#  962                   1                     2   1
#  963                   1                     2   1
#  964                   1                     2   1
#  965                   0                     0   1
#  966                   0                     0   1
#
#  [967 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        73      77    75.00           1.0      -0.36      -0.35       -0.35
#  1        76      77    76.50           1.0      -0.36      -0.35       -0.35
#  2        72      76    73.80           1.0      -0.36      -0.35       -0.35
#  3        72      75    73.67           1.0      -0.36      -0.35       -0.35
#  4        75      77    76.00           1.0      -0.36      -0.35       -0.36
#  ..      ...     ...      ...           ...        ...        ...         ...
#  959      70      76    72.50           1.0      -0.38      -0.36       -0.37
#  960      70      72    71.17           1.0      -0.45      -0.36       -0.37
#  961      70      75    72.50           1.0      -0.41      -0.39       -0.39
#  962      71      74    72.60           1.0      -0.40      -0.38       -0.39
#  963      71      72    71.67           1.0      -0.39      -0.38       -0.39
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.01       0.01        0.01       0.93       0.94        0.93
#  1         0.00       0.01        0.01       0.93       0.94        0.93
#  2         0.01       0.01        0.01       0.93       0.94        0.93
#  3         0.01       0.01        0.01       0.93       0.94        0.93
#  4         0.01       0.01        0.01       0.93       0.94        0.93
#  ..         ...        ...         ...        ...        ...         ...
#  959      -0.11      -0.04       -0.09      -0.96      -0.91       -0.93
#  960      -0.16       0.01       -0.09      -0.94      -0.84       -0.93
#  961      -0.08      -0.05       -0.07      -0.93      -0.91       -0.92
#  962      -0.08      -0.02       -0.07      -0.93      -0.89       -0.92
#  963      -0.08      -0.06       -0.07      -0.93      -0.92       -0.92
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   2
#  1                     0                     0   2
#  2                     0                     0   2
#  3                     0                     0   2
#  4                     0                     0   2
#  ..                  ...                   ...  ..
#  959                   0                     0   2
#  960                   0                     0   2
#  961                   0                     0   2
#  962                   0                     0   2
#  963                   0                     0   2
#
#  [964 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      49.0    54.0    50.83           1.0      -0.43      -0.20       -0.33
#  1      50.0    54.0    52.40           1.0      -0.51      -0.29       -0.41
#  2      53.0    54.0    53.83           1.0      -0.49      -0.35       -0.39
#  3      56.0    68.0    60.50           1.0      -0.45      -0.34       -0.39
#  4      51.0    52.0    51.67           1.0      -0.55      -0.09       -0.31
#  ..      ...     ...      ...           ...        ...        ...         ...
#  984     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  985     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  986     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  987     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  988     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.76       0.99        0.90      -0.14       0.53        0.23
#  1         0.79       1.01        0.90      -0.13       0.22        0.06
#  2         0.86       0.99        0.92      -0.18       0.04        0.00
#  3         0.80       0.97        0.91       0.02       0.39        0.13
#  4         0.32       1.06        0.82      -0.95       0.44       -0.15
#  ..         ...        ...         ...        ...        ...         ...
#  984        NaN        NaN         NaN        NaN        NaN         NaN
#  985        NaN        NaN         NaN        NaN        NaN         NaN
#  986        NaN        NaN         NaN        NaN        NaN         NaN
#  987        NaN        NaN         NaN        NaN        NaN         NaN
#  988        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   3
#  1                     0                     0   3
#  2                     0                     0   3
#  3                     0                     0   3
#  4                     0                     0   3
#  ..                  ...                   ...  ..
#  984                   1                     1   3
#  985                   0                     0   3
#  986                   0                     0   3
#  987                   0                     0   3
#  988                   0                     0   3
#
#  [989 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      58.0    60.0    59.00          1.02      -0.83      -0.06       -0.55
#  1      57.0    60.0    58.20          1.00      -0.40      -0.35       -0.38
#  2      62.0    69.0    64.57          1.02      -1.01       0.05       -0.42
#  3      59.0    59.0    59.00          1.01      -1.03       0.61       -0.59
#  4      59.0    61.0    59.80          1.00      -0.42      -0.30       -0.36
#  ..      ...     ...      ...           ...        ...        ...         ...
#  982     NaN     NaN      NaN          1.00      -1.02      -0.31       -0.41
#  983     NaN     NaN      NaN          1.00      -0.33      -0.32       -0.33
#  984     NaN     NaN      NaN          1.00      -0.33      -0.32       -0.33
#  985     NaN     NaN      NaN          1.00      -0.97      -0.32       -0.53
#  986     NaN     NaN      NaN          1.00      -0.98      -0.18       -0.39
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.10       0.55       -0.55      -1.22      -0.23       -0.57
#  1        -0.04       0.03       -0.02      -0.95      -0.91       -0.92
#  2        -2.04       0.16       -0.35      -1.58       0.71       -0.56
#  3        -1.00       0.67       -0.50      -2.02       0.63       -0.22
#  4        -0.51      -0.23       -0.39      -0.98      -0.71       -0.84
#  ..         ...        ...         ...        ...        ...         ...
#  982      -0.70       0.82       -0.06      -1.12       0.71       -0.53
#  983       0.11       0.13        0.12      -0.94      -0.93       -0.94
#  984       0.12       0.14        0.13      -0.94      -0.93       -0.94
#  985      -0.14       0.94        0.29      -0.96       1.28       -0.48
#  986      -0.53       1.07        0.78      -0.45       0.30       -0.07
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   4
#  1                     0                     0   4
#  2                     0                     0   4
#  3                     0                     0   4
#  4                     0                     0   4
#  ..                  ...                   ...  ..
#  982                   0                     0   4
#  983                   0                     0   4
#  984                   0                     0   4
#  985                   0                     0   4
#  986                   0                     0   4
#
#  [987 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      73.0    74.0    73.60          1.00      -0.34      -0.33       -0.34
#  1      72.0    75.0    73.33          1.00      -0.34      -0.32       -0.33
#  2      72.0    76.0    72.67          1.04      -0.95       1.04       -0.26
#  3      71.0    74.0    71.67          1.00      -0.81       1.12       -0.14
#  4      71.0    72.0    71.83          0.99      -0.63       0.49       -0.32
#  ..      ...     ...      ...           ...        ...        ...         ...
#  977    71.0    76.0    73.67          0.98      -0.90       0.27       -0.39
#  978    71.0    76.0    73.80          1.06      -0.97      -0.35       -0.50
#  979    71.0    76.0    72.50          1.00      -0.92       0.95       -0.09
#  980    73.0    75.0    74.00          1.02       0.36       1.12        0.53
#  981    70.0    77.0    72.29          1.00       0.33       0.38        0.36
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.79       0.80        0.80      -0.50      -0.49       -0.50
#  1         0.79       0.80        0.79      -0.51      -0.49       -0.50
#  2        -0.51       0.89        0.52      -1.41       0.60       -0.55
#  3        -1.03       0.72       -0.06      -0.88       0.96       -0.35
#  4        -0.79       0.15       -0.28      -1.11      -0.30       -0.83
#  ..         ...        ...         ...        ...        ...         ...
#  977      -0.99       0.34       -0.26      -0.90       0.47       -0.42
#  978      -0.42       1.17        0.17      -2.30       0.21       -0.79
#  979      -1.03       1.17       -0.16      -0.95       0.12       -0.63
#  980       0.14       0.74        0.52      -0.78      -0.24       -0.65
#  981       0.64       0.70        0.67      -0.67      -0.63       -0.65
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   5
#  1                     0                     0   5
#  2                     0                     0   5
#  3                     0                     0   5
#  4                     0                     0   5
#  ..                  ...                   ...  ..
#  977                   1                     2   5
#  978                   0                     5   5
#  979                   0                     0   5
#  980                   0                     0   5
#  981                   0                     0   5
#
#  [982 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        63      65    63.50          1.01      -0.13      -0.10       -0.11
#  1        57      61    59.17          1.01      -0.12      -0.10       -0.11
#  2        58      61    59.43          1.01      -0.13      -0.11       -0.12
#  3        59      60    59.17          1.01      -0.13      -0.11       -0.12
#  4        54      59    55.67          1.01      -0.13      -0.11       -0.12
#  ..      ...     ...      ...           ...        ...        ...         ...
#  963      55      81    75.83          1.02      -1.08       0.79       -0.86
#  964      52      54    53.00          1.00      -0.95      -0.94       -0.94
#  965      50      51    50.17          1.00      -0.95      -0.94       -0.94
#  966      49      50    49.83          1.00      -0.95      -0.94       -0.94
#  967      50      50    50.00          1.00      -0.95      -0.94       -0.94
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.97       1.01        0.99      -0.21      -0.12       -0.17
#  1         0.97       1.00        0.98      -0.21      -0.17       -0.20
#  2         0.95       0.98        0.97      -0.29      -0.19       -0.23
#  3         0.96       1.00        0.97      -0.27      -0.13       -0.22
#  4         0.96       0.98        0.97      -0.24      -0.18       -0.22
#  ..         ...        ...         ...        ...        ...         ...
#  963      -1.17       0.92       -0.01      -1.49       0.53       -0.38
#  964       0.03       0.05        0.04      -0.34      -0.33       -0.33
#  965       0.03       0.05        0.04      -0.34      -0.33       -0.33
#  966       0.03       0.05        0.04      -0.34      -0.32       -0.33
#  967       0.04       0.06        0.05      -0.33      -0.32       -0.33
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   6
#  1                     0                     0   6
#  2                     0                     0   6
#  3                     0                     0   6
#  4                     0                     0   6
#  ..                  ...                   ...  ..
#  963                   0                     0   6
#  964                   0                     0   6
#  965                   0                     0   6
#  966                   0                     0   6
#  967                   0                     0   6
#
#  [968 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        69      77    74.29          1.00      -0.01       0.00       -0.00
#  1        75      77    76.40          1.00      -0.01       0.00       -0.00
#  2        75      77    75.67          1.00      -0.00       0.00       -0.00
#  3        74      75    74.50          1.00      -0.00       0.00       -0.00
#  4        70      73    71.17          1.00      -0.39       0.07       -0.01
#  ..      ...     ...      ...           ...        ...        ...         ...
#  411      68      71    69.00          0.99      -0.68       0.26        0.04
#  412      68      71    69.40          0.99      -0.25      -0.22       -0.23
#  413      67      71    69.00          0.99      -0.24      -0.22       -0.23
#  414      72      76    73.80          0.99      -0.23      -0.22       -0.23
#  415      72      74    73.33          0.99      -0.23      -0.22       -0.23
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.00      -0.99       -0.99       0.09       0.11        0.10
#  1        -1.00      -0.99       -0.99       0.09       0.11        0.10
#  2        -1.00      -0.99       -0.99       0.09       0.11        0.10
#  3        -1.00      -0.99       -0.99       0.09       0.11        0.10
#  4        -1.23      -0.32       -0.98      -0.34       0.46        0.12
#  ..         ...        ...         ...        ...        ...         ...
#  411      -0.98       0.64       -0.52      -1.52       0.19       -0.26
#  412       0.09       0.17        0.14      -0.96      -0.93       -0.95
#  413       0.12       0.14        0.13      -0.96      -0.95       -0.95
#  414       0.13       0.14        0.13      -0.96      -0.95       -0.95
#  415       0.13       0.14        0.13      -0.96      -0.95       -0.96
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   7
#  1                     0                     0   7
#  2                     0                     0   7
#  3                     0                     0   7
#  4                     0                     0   7
#  ..                  ...                   ...  ..
#  411                   1                     2   7
#  412                   1                     2   7
#  413                   1                     2   7
#  414                   1                     2   7
#  415                   1                     2   7
#
#  [416 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      63.0    64.0    63.33          1.02      -0.52       1.11        0.54
#  1      64.0    65.0    64.57          1.00      -1.06       1.52       -0.26
#  2      64.0    67.0    66.00          1.00      -1.16       0.37       -0.55
#  3      55.0    65.0    59.83          0.99      -0.64      -0.54       -0.56
#  4      68.0    71.0    68.50          0.99      -0.57      -0.55       -0.56
#  ..      ...     ...      ...           ...        ...        ...         ...
#  971     NaN     NaN      NaN          1.00      -0.92      -0.05       -0.31
#  972     NaN     NaN      NaN          1.00      -0.87      -0.45       -0.84
#  973     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  974     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  975     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.33       1.13        0.56      -1.22      -0.14       -0.48
#  1        -0.66       1.05        0.25      -1.61       0.97       -0.27
#  2        -1.12       0.59       -0.24      -0.94       0.95       -0.58
#  3        -0.43      -0.27       -0.40      -0.73      -0.70       -0.72
#  4        -0.42      -0.39       -0.41      -0.72      -0.70       -0.71
#  ..         ...        ...         ...        ...        ...         ...
#  971      -0.98      -0.03       -0.76      -0.03       0.49        0.38
#  972      -0.73      -0.33       -0.52      -0.56       0.21        0.03
#  973        NaN        NaN         NaN        NaN        NaN         NaN
#  974        NaN        NaN         NaN        NaN        NaN         NaN
#  975        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   8
#  1                     0                     0   8
#  2                     0                     0   8
#  3                     0                     0   8
#  4                     0                     0   8
#  ..                  ...                   ...  ..
#  971                   0                     5   8
#  972                   0                     5   8
#  973                   0                     5   8
#  974                   0                     0   8
#  975                   0                     0   8
#
#  [976 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        53      56    54.50          1.00      -0.02      -0.01       -0.02
#  1        50      50    50.00          1.00      -0.09       0.08       -0.02
#  2        47      50    48.40          1.00      -0.03      -0.02       -0.03
#  3        48      49    48.86          1.00      -0.03      -0.02       -0.02
#  4        49      50    49.40          1.00      -0.03      -0.01       -0.02
#  ..      ...     ...      ...           ...        ...        ...         ...
#  504      47      48    47.33          0.99      -0.36      -0.35       -0.35
#  505      47      51    48.00          0.99      -0.36      -0.35       -0.35
#  506      45      49    46.20          0.99      -0.36      -0.35       -0.35
#  507      45      49    46.50          0.99      -0.36      -0.35       -0.35
#  508      46      48    46.60          0.99      -0.36      -0.35       -0.35
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.72       0.73        0.72      -0.69      -0.66       -0.68
#  1         0.06       0.72        0.61      -0.99      -0.68       -0.78
#  2         0.58       0.59        0.58      -0.81      -0.80       -0.81
#  3         0.58       0.59        0.58      -0.82      -0.80       -0.81
#  4         0.58       0.59        0.58      -0.81      -0.81       -0.81
#  ..         ...        ...         ...        ...        ...         ...
#  504       0.54       0.54        0.54      -0.76      -0.75       -0.76
#  505       0.54       0.55        0.54      -0.76      -0.75       -0.76
#  506       0.54       0.55        0.54      -0.76      -0.75       -0.76
#  507       0.54       0.54        0.54      -0.76      -0.75       -0.76
#  508       0.53       0.55        0.54      -0.76      -0.75       -0.76
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0   9
#  1                     0                     0   9
#  2                     0                     0   9
#  3                     0                     0   9
#  4                     0                     0   9
#  ..                  ...                   ...  ..
#  504                   0                     0   9
#  505                   0                     0   9
#  506                   0                     0   9
#  507                   0                     0   9
#  508                   0                     0   9
#
#  [509 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      49.0    49.0    49.00          1.00      -0.86      -0.33       -0.48
#  1      48.0    65.0    53.67          1.00      -0.81      -0.38       -0.49
#  2      47.0    48.0    47.40          0.99      -0.93      -0.29       -0.43
#  3      47.0    59.0    57.00          0.99      -0.65      -0.36       -0.39
#  4      49.0    56.0    51.50          0.99      -0.39      -0.38       -0.38
#  ..      ...     ...      ...           ...        ...        ...         ...
#  964     NaN     NaN      NaN          1.00       0.15       0.16        0.16
#  965    46.0    47.0    46.60          1.00      -0.71       0.17        0.03
#  966    46.0    48.0    46.67          1.00      -0.65       0.08       -0.40
#  967    48.0    50.0    48.83          1.00      -1.00       0.13       -0.46
#  968    48.0    49.0    48.20          0.99      -0.99      -0.22       -0.91
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.50       0.90        0.40      -1.42       1.03       -0.65
#  1         0.01       1.12        0.28      -1.05      -0.15       -0.80
#  2         0.07       0.55        0.28      -1.36      -0.16       -0.83
#  3         0.18       0.75        0.25      -0.93      -0.18       -0.87
#  4         0.25       0.26        0.26      -0.88      -0.88       -0.88
#  ..         ...        ...         ...        ...        ...         ...
#  964      -0.24      -0.22       -0.23      -0.96      -0.95       -0.96
#  965      -0.78       0.04       -0.25      -0.97       1.18       -0.64
#  966      -0.37       0.41       -0.14       0.80       1.32        0.90
#  967      -0.90       1.03       -0.10      -1.32       1.04        0.14
#  968      -0.51       0.00       -0.17      -1.05      -0.13       -0.33
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  10
#  1                     0                     0  10
#  2                     0                     0  10
#  3                     0                     0  10
#  4                     0                     0  10
#  ..                  ...                   ...  ..
#  964                   0                     0  10
#  965                   0                     0  10
#  966                   0                     0  10
#  967                   0                     0  10
#  968                   0                     0  10
#
#  [969 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        82      84    83.00          1.00      -0.92      -0.05       -0.47
#  1        75      80    78.00          0.99      -0.92      -0.31       -0.76
#  2        75      80    76.50          1.00      -0.50      -0.48       -0.49
#  3        70      75    71.80          1.00      -0.53      -0.48       -0.49
#  4        68      71    69.67          1.00      -0.49      -0.48       -0.49
#  ..      ...     ...      ...           ...        ...        ...         ...
#  974      68      82    75.00          1.00      -0.41      -0.40       -0.40
#  975      62      82    68.83          1.00      -0.41      -0.40       -0.40
#  976      62      72    66.20          1.00      -0.41      -0.40       -0.40
#  977      61      66    63.57          1.00      -0.40      -0.40       -0.40
#  978      59      60    59.40          1.00      -0.41      -0.40       -0.40
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.10      -0.06       -0.21      -1.28       0.16       -0.78
#  1        -0.95       0.17       -0.49      -1.05       0.24       -0.16
#  2        -0.86      -0.84       -0.85       0.16       0.18        0.18
#  3        -0.85      -0.83       -0.84       0.16       0.22        0.19
#  4        -0.85      -0.84       -0.85       0.19       0.20        0.19
#  ..         ...        ...         ...        ...        ...         ...
#  974      -0.91      -0.90       -0.91       0.10       0.11        0.10
#  975      -0.91      -0.90       -0.91       0.10       0.11        0.10
#  976      -0.91      -0.90       -0.91       0.10       0.10        0.10
#  977      -0.91      -0.90       -0.91       0.10       0.10        0.10
#  978      -0.91      -0.90       -0.91       0.09       0.10        0.10
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  11
#  1                     0                     0  11
#  2                     0                     0  11
#  3                     0                     0  11
#  4                     0                     0  11
#  ..                  ...                   ...  ..
#  974                   0                     5  11
#  975                   0                     5  11
#  976                   0                     5  11
#  977                   0                     5  11
#  978                   0                     5  11
#
#  [979 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      50.0    55.0    51.40          1.01      -0.89      -0.20       -0.47
#  1      51.0    58.0    54.86          0.99      -0.76      -0.32       -0.37
#  2      56.0    68.0    61.60          1.00      -1.05      -0.34       -0.52
#  3      51.0    56.0    53.17          1.00      -1.04      -0.91       -0.97
#  4      48.0    51.0    49.43          1.01      -1.03      -0.29       -0.79
#  ..      ...     ...      ...           ...        ...        ...         ...
#  561    50.0    51.0    50.17          1.00      -0.35      -0.34       -0.35
#  562    52.0    59.0    55.50          1.00      -0.35      -0.34       -0.35
#  563    51.0    54.0    52.20          1.00      -0.36      -0.32       -0.34
#  564    51.0    53.0    51.83          1.00      -0.34      -0.34       -0.34
#  565    51.0    63.0    53.83          1.00      -0.34      -0.34       -0.34
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.18       0.24       -0.81      -0.64       1.09        0.13
#  1        -1.07      -0.50       -0.92      -0.48       0.75        0.02
#  2        -0.98       0.21       -0.72      -0.73       0.13       -0.03
#  3        -0.12       0.10       -0.05      -0.31      -0.15       -0.23
#  4        -1.30       0.38       -0.15      -1.27      -0.02       -0.35
#  ..         ...        ...         ...        ...        ...         ...
#  561      -0.14      -0.14       -0.14       0.92       0.93        0.92
#  562      -0.14      -0.14       -0.14       0.92       0.93        0.92
#  563      -0.16      -0.14       -0.14       0.92       0.94        0.92
#  564      -0.15      -0.14       -0.14       0.92       0.93        0.93
#  565      -0.15      -0.14       -0.14       0.92       0.93        0.93
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  12
#  1                     0                     0  12
#  2                     0                     0  12
#  3                     0                     0  12
#  4                     0                     0  12
#  ..                  ...                   ...  ..
#  561                   0                     0  12
#  562                   0                     0  12
#  563                   0                     0  12
#  564                   0                     0  12
#  565                   0                     0  12
#
#  [566 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      72.0    77.0    73.33          0.99      -0.46      -0.29       -0.40
#  1      70.0    75.0    71.60          1.00      -0.89       0.14       -0.42
#  2      71.0    75.0    72.29          0.99      -0.73      -0.27       -0.41
#  3      70.0    72.0    71.20          1.00      -0.98       0.36       -0.63
#  4      68.0    70.0    68.80          0.99      -0.99      -0.27       -0.50
#  ..      ...     ...      ...           ...        ...        ...         ...
#  459     NaN     NaN      NaN          1.00       0.37       0.38        0.38
#  460     NaN     NaN      NaN          1.00       0.37       0.38        0.38
#  461     NaN     NaN      NaN          1.00       0.38       0.38        0.38
#  462     NaN     NaN      NaN          1.00       0.38       0.38        0.38
#  463    68.0    68.0    68.00          1.00       0.12       0.41        0.37
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.16       0.45        0.03      -0.96      -0.85       -0.90
#  1        -0.31       0.88        0.25      -1.08      -0.24       -0.80
#  2        -0.50       0.51        0.10      -1.02      -0.40       -0.89
#  3        -1.16       0.88       -0.06      -1.19      -0.09       -0.61
#  4        -0.48       0.31        0.07      -1.16      -0.01       -0.74
#  ..         ...        ...         ...        ...        ...         ...
#  459       0.72       0.73        0.73      -0.58      -0.57       -0.57
#  460       0.72       0.73        0.73      -0.58      -0.56       -0.57
#  461       0.72       0.73        0.73      -0.58      -0.56       -0.57
#  462       0.72       0.73        0.73      -0.58      -0.56       -0.57
#  463       0.62       0.81        0.73      -0.74      -0.51       -0.57
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  13
#  1                     0                     0  13
#  2                     0                     0  13
#  3                     0                     0  13
#  4                     0                     0  13
#  ..                  ...                   ...  ..
#  459                   1                     2  13
#  460                   1                     2  13
#  461                   1                     2  13
#  462                   1                     2  13
#  463                   1                     2  13
#
#  [464 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      56.0    59.0    58.00          1.01      -0.32       0.91        0.06
#  1      54.0    55.0    54.86          1.06      -0.61       1.12       -0.21
#  2      54.0    54.0    54.00          1.00      -0.75       0.17       -0.18
#  3      54.0    59.0    56.00          1.00      -0.81       0.01       -0.09
#  4      52.0    54.0    53.17          1.00      -0.03      -0.00       -0.02
#  ..      ...     ...      ...           ...        ...        ...         ...
#  972    58.0    62.0    59.50          1.00      -0.03      -0.03       -0.03
#  973    57.0    59.0    57.83          1.01      -1.08       0.04       -0.56
#  974    57.0    62.0    60.20          0.99      -1.01      -0.18       -0.80
#  975    59.0    63.0    60.50           NaN        NaN        NaN         NaN
#  976    61.0    64.0    62.40           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.39       0.81        0.20      -1.30      -0.45       -0.85
#  1        -0.99       0.54        0.32      -3.16       0.76       -0.70
#  2        -0.72       0.78        0.48      -0.94      -0.41       -0.69
#  3        -0.80       0.68        0.29      -0.93       0.54       -0.75
#  4         0.52       0.55        0.53      -0.86      -0.84       -0.84
#  ..         ...        ...         ...        ...        ...         ...
#  972      -0.70      -0.69       -0.69       0.72       0.73        0.72
#  973      -0.79       0.62       -0.27      -0.66       1.01        0.29
#  974      -0.95       0.19       -0.34      -0.54       0.43        0.05
#  975        NaN        NaN         NaN        NaN        NaN         NaN
#  976        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  14
#  1                     0                     0  14
#  2                     0                     0  14
#  3                     0                     0  14
#  4                     0                     0  14
#  ..                  ...                   ...  ..
#  972                   1                     2  14
#  973                   1                     2  14
#  974                   1                     2  14
#  975                   1                     2  14
#  976                   1                     2  14
#
#  [977 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      75.0    77.0    76.33          1.00      -0.91      -0.61       -0.74
#  1      76.0    88.0    78.40          1.00      -0.95      -0.45       -0.69
#  2      83.0    86.0    85.50          1.01      -1.07      -0.16       -0.70
#  3      70.0    77.0    71.67          1.00      -0.27      -0.26       -0.27
#  4      68.0    69.0    68.67          1.00      -0.27      -0.26       -0.26
#  ..      ...     ...      ...           ...        ...        ...         ...
#  753    62.0    70.0    65.00          1.00      -0.04      -0.03       -0.03
#  754    59.0    69.0    64.60          1.00      -0.04      -0.02       -0.03
#  755    58.0    65.0    60.50          1.00      -0.04      -0.02       -0.03
#  756    60.0    67.0    63.17          1.00      -0.04      -0.02       -0.03
#  757    65.0    67.0    65.60          1.00      -0.04      -0.02       -0.03
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.33       0.73        0.25      -0.72      -0.14       -0.52
#  1        -0.30       0.88        0.36      -0.77      -0.07       -0.51
#  2        -1.27       0.72       -0.05      -1.28       0.74       -0.47
#  3         0.47       0.48        0.48      -0.85      -0.83       -0.84
#  4         0.47       0.48        0.48      -0.85      -0.84       -0.84
#  ..         ...        ...         ...        ...        ...         ...
#  753      -0.58      -0.56       -0.57      -0.83      -0.82       -0.82
#  754      -0.58      -0.56       -0.57      -0.83      -0.82       -0.82
#  755      -0.58      -0.56       -0.57      -0.83      -0.81       -0.82
#  756      -0.60      -0.56       -0.57      -0.84      -0.79       -0.82
#  757      -0.58      -0.56       -0.57      -0.83      -0.81       -0.82
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  15
#  1                     0                     0  15
#  2                     0                     0  15
#  3                     0                     0  15
#  4                     0                     0  15
#  ..                  ...                   ...  ..
#  753                   0                     5  15
#  754                   0                     0  15
#  755                   0                     0  15
#  756                   0                     0  15
#  757                   0                     0  15
#
#  [758 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      55.0    59.0    57.40          1.00      -0.88       0.61       -0.06
#  1      56.0    59.0    57.86          0.99      -0.05       0.40        0.08
#  2      57.0    57.0    57.00          0.99       0.07       0.08        0.08
#  3      58.0    67.0    62.83          0.99       0.07       0.08        0.08
#  4      59.0    61.0    59.60          1.00      -0.29       0.08       -0.00
#  ..      ...     ...      ...           ...        ...        ...         ...
#  956     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  957     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  958     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  959     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  960     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.32       1.46        0.28      -1.09       0.27       -0.76
#  1        -0.61       0.57        0.35      -1.31      -0.66       -0.91
#  2         0.25       0.27        0.26      -0.96      -0.95       -0.96
#  3         0.26       0.26        0.26      -0.96      -0.95       -0.96
#  4        -0.02       1.09        0.48      -0.96       1.03       -0.44
#  ..         ...        ...         ...        ...        ...         ...
#  956        NaN        NaN         NaN        NaN        NaN         NaN
#  957        NaN        NaN         NaN        NaN        NaN         NaN
#  958        NaN        NaN         NaN        NaN        NaN         NaN
#  959        NaN        NaN         NaN        NaN        NaN         NaN
#  960        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  16
#  1                     0                     0  16
#  2                     0                     0  16
#  3                     0                     0  16
#  4                     0                     0  16
#  ..                  ...                   ...  ..
#  956                   0                     5  16
#  957                   0                     5  16
#  958                   0                     5  16
#  959                   0                     5  16
#  960                   0                     5  16
#
#  [961 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      70.0    75.0    72.20          0.99      -0.35      -0.31       -0.32
#  1      71.0    77.0    74.43          1.01      -0.97       0.67       -0.33
#  2      62.0    67.0    63.83          1.00      -1.39       0.24       -0.31
#  3      61.0    63.0    62.17          0.99      -0.31      -0.29       -0.30
#  4      62.0    67.0    64.50          0.99      -0.32      -0.28       -0.30
#  ..      ...     ...      ...           ...        ...        ...         ...
#  976     NaN     NaN      NaN          1.01      -1.23       0.60        0.00
#  977     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  978     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  979     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  980     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.25       0.34        0.29      -0.90      -0.88       -0.89
#  1        -1.15       1.47       -0.03      -1.17       1.04       -0.54
#  2        -0.64       0.26       -0.16      -1.40      -0.66       -0.93
#  3        -0.14      -0.11       -0.12      -0.96      -0.93       -0.94
#  4        -0.14      -0.10       -0.12      -0.96      -0.92       -0.94
#  ..         ...        ...         ...        ...        ...         ...
#  976      -1.07       1.03       -0.13      -1.29       0.92        0.00
#  977        NaN        NaN         NaN        NaN        NaN         NaN
#  978        NaN        NaN         NaN        NaN        NaN         NaN
#  979        NaN        NaN         NaN        NaN        NaN         NaN
#  980        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  17
#  1                     0                     0  17
#  2                     0                     0  17
#  3                     0                     0  17
#  4                     0                     0  17
#  ..                  ...                   ...  ..
#  976                   1                     2  17
#  977                   1                     2  17
#  978                   1                     2  17
#  979                   1                     2  17
#  980                   0                     0  17
#
#  [981 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        84      95    87.20          1.00      -0.18       0.02       -0.17
#  1        78      85    80.50          1.00      -0.22      -0.05       -0.11
#  2        82      84    82.83          1.00      -0.53       1.03        0.19
#  3        82      86    83.17          0.99      -0.51       0.89        0.16
#  4        86      87    86.33          1.00      -0.37       0.37       -0.21
#  ..      ...     ...      ...           ...        ...        ...         ...
#  469      77      79    77.67          1.00       0.37       0.37        0.37
#  470      76      80    77.50          1.00      -0.31       0.54        0.27
#  471      77      78    77.33          1.00      -0.10      -0.06       -0.07
#  472      75      78    76.40          1.00      -0.07      -0.07       -0.07
#  473      77      89    80.83          1.00      -0.08      -0.07       -0.07
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.61       1.02        0.86      -0.50      -0.07       -0.48
#  1         0.84       1.00        0.92      -0.51       0.43        0.20
#  2        -0.03       2.01        0.77      -0.86       1.17       -0.13
#  3        -0.56       2.00        0.57      -1.14       1.51       -0.34
#  4        -0.11       1.71        0.81      -0.74      -0.23       -0.55
#  ..         ...        ...         ...        ...        ...         ...
#  469      -0.91      -0.91       -0.91       0.19       0.20        0.20
#  470      -0.93       0.37       -0.67       0.15       1.06        0.41
#  471      -0.47      -0.41       -0.45       0.88       0.91        0.89
#  472      -0.46      -0.45       -0.46       0.88       0.89        0.88
#  473      -0.46      -0.42       -0.46       0.88       0.90        0.89
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  18
#  1                     0                     0  18
# ...
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  24
#  1                     0                     0  24
#  2                     0                     0  24
#  3                     0                     0  24
#  4                     0                     0  24
#  ..                  ...                   ...  ..
#  943                   0                     0  24
#  944                   0                     0  24
#  945                   0                     0  24
#  946                   0                     0  24
#  947                   0                     0  24
#
#  [948 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        59      59    59.00          1.00      -1.46       1.03       -0.36
#  1        59      61    59.67          0.99      -0.37      -0.36       -0.36
#  2        59      64    60.83          0.99      -0.38      -0.36       -0.37
#  3        59      60    59.17          0.99      -0.40      -0.34       -0.37
#  4        59      59    59.00          0.99      -0.38      -0.37       -0.37
#  ..      ...     ...      ...           ...        ...        ...         ...
#  960      59      62    60.67          0.99      -0.17      -0.16       -0.17
#  961      60      62    61.00          0.99      -0.17      -0.16       -0.17
#  962      55      64    60.83          0.99      -0.17      -0.16       -0.17
#  963      54      63    60.33          0.99      -0.17      -0.16       -0.17
#  964      62      63    62.80          0.99      -0.17      -0.16       -0.17
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -1.02       1.07        0.10      -1.19       0.54       -0.74
#  1         0.12       0.14        0.13      -0.92      -0.91       -0.91
#  2         0.12       0.19        0.14      -0.92      -0.87       -0.91
#  3         0.12       0.33        0.23      -0.92      -0.88       -0.89
#  4         0.24       0.27        0.25      -0.89      -0.88       -0.88
#  ..         ...        ...         ...        ...        ...         ...
#  960       0.22       0.23        0.22      -0.96      -0.95       -0.95
#  961       0.21       0.23        0.22      -0.96      -0.95       -0.95
#  962       0.21       0.23        0.22      -0.96      -0.95       -0.95
#  963       0.21       0.23        0.22      -0.96      -0.95       -0.95
#  964       0.22       0.23        0.22      -0.96      -0.95       -0.95
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  25
#  1                     0                     0  25
#  2                     0                     0  25
#  3                     0                     0  25
#  4                     0                     0  25
#  ..                  ...                   ...  ..
#  960                   1                     1  25
#  961                   0                     0  25
#  962                   1                     1  25
#  963                   1                     1  25
#  964                   0                     0  25
#
#  [965 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      58.0    68.0    61.00           1.0       0.40       0.41         0.4
#  1      74.0    83.0    79.43           1.0       0.40       0.41         0.4
#  2      76.0    81.0    79.17           1.0       0.39       0.40         0.4
#  3      79.0    87.0    83.00           1.0       0.40       0.40         0.4
#  4      73.0    89.0    80.67           1.0       0.40       0.40         0.4
#  ..      ...     ...      ...           ...        ...        ...         ...
#  965     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  966     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  967     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  968     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  969     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.46       0.46        0.46      -0.80      -0.79       -0.79
#  1         0.45       0.47        0.46      -0.80      -0.78       -0.79
#  2         0.46       0.48        0.46      -0.80      -0.78       -0.79
#  3         0.46       0.48        0.47      -0.79      -0.78       -0.79
#  4         0.46       0.47        0.47      -0.79      -0.78       -0.79
#  ..         ...        ...         ...        ...        ...         ...
#  965        NaN        NaN         NaN        NaN        NaN         NaN
#  966        NaN        NaN         NaN        NaN        NaN         NaN
#  967        NaN        NaN         NaN        NaN        NaN         NaN
#  968        NaN        NaN         NaN        NaN        NaN         NaN
#  969        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  26
#  1                     0                     0  26
#  2                     0                     0  26
#  3                     0                     0  26
#  4                     0                     0  26
#  ..                  ...                   ...  ..
#  965                   1                     2  26
#  966                   1                     2  26
#  967                   1                     2  26
#  968                   1                     2  26
#  969                   0                     0  26
#
#  [970 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      67.0    68.0    67.17          1.00      -0.55      -0.36       -0.49
#  1      59.0    66.0    61.67          1.00      -0.49      -0.48       -0.49
#  2      59.0    60.0    59.17          1.00      -0.51      -0.48       -0.50
#  3      59.0    59.0    59.00          1.00      -0.61      -0.43       -0.50
#  4      59.0    61.0    59.67          1.01      -0.68       0.20       -0.46
#  ..      ...     ...      ...           ...        ...        ...         ...
#  959    55.0    67.0    59.50           NaN        NaN        NaN         NaN
#  960    50.0    62.0    58.40           NaN        NaN        NaN         NaN
#  961     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  962     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#  963     NaN     NaN      NaN           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.07      -0.00       -0.02      -0.99      -0.81       -0.88
#  1        -0.03      -0.00       -0.02      -0.88      -0.87       -0.88
#  2        -0.04      -0.00       -0.01      -0.89      -0.85       -0.87
#  3        -0.04       0.05       -0.00      -0.91      -0.80       -0.87
#  4        -0.70       0.70        0.04      -1.00      -0.58       -0.87
#  ..         ...        ...         ...        ...        ...         ...
#  959        NaN        NaN         NaN        NaN        NaN         NaN
#  960        NaN        NaN         NaN        NaN        NaN         NaN
#  961        NaN        NaN         NaN        NaN        NaN         NaN
#  962        NaN        NaN         NaN        NaN        NaN         NaN
#  963        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  27
#  1                     0                     0  27
#  2                     0                     0  27
#  3                     0                     0  27
#  4                     0                     0  27
#  ..                  ...                   ...  ..
#  959                   0                     5  27
#  960                   0                     5  27
#  961                   0                     5  27
#  962                   0                     5  27
#  963                   0                     5  27
#
#  [964 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        58      60    58.67           1.0      -0.37      -0.35       -0.36
#  1        60      61    60.40           1.0      -1.03      -0.31       -0.39
#  2        64      70    67.83           1.0      -0.81      -0.25       -0.34
#  3        63      68    64.40           1.0      -0.60      -0.30       -0.33
#  4        60      61    60.17           1.0      -0.35      -0.34       -0.34
#  ..      ...     ...      ...           ...        ...        ...         ...
#  969      54      57    55.33           NaN        NaN        NaN         NaN
#  970      57      80    70.17           NaN        NaN        NaN         NaN
#  971      81      81    81.00           NaN        NaN        NaN         NaN
#  972      69      74    72.33           NaN        NaN        NaN         NaN
#  973      74      77    76.00           NaN        NaN        NaN         NaN
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0         0.14       0.17        0.15      -0.93      -0.91       -0.92
#  1        -0.48       0.56        0.15      -0.98       0.19       -0.87
#  2        -0.06       0.47        0.27      -0.98      -0.07       -0.89
#  3        -0.13       0.58        0.29      -0.93      -0.47       -0.89
#  4         0.31       0.32        0.32      -0.89      -0.89       -0.89
#  ..         ...        ...         ...        ...        ...         ...
#  969        NaN        NaN         NaN        NaN        NaN         NaN
#  970        NaN        NaN         NaN        NaN        NaN         NaN
#  971        NaN        NaN         NaN        NaN        NaN         NaN
#  972        NaN        NaN         NaN        NaN        NaN         NaN
#  973        NaN        NaN         NaN        NaN        NaN         NaN
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  28
#  1                     0                     0  28
#  2                     0                     0  28
#  3                     0                     0  28
#  4                     0                     0  28
#  ..                  ...                   ...  ..
#  969                   0                     0  28
#  970                   1                     1  28
#  971                   0                     0  28
#  972                   1                     2  28
#  973                   1                     2  28
#
#  [974 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0        62      65    63.20          1.00      -0.62       1.14        0.77
#  1        64      69    66.50          1.03      -0.57       1.14        0.32
#  2        69      69    69.00          1.01      -1.01       0.02       -0.41
#  3        69      72    70.00          1.00      -0.58       0.07       -0.15
#  4        72      74    73.00          1.00      -1.13      -0.11       -0.62
#  ..      ...     ...      ...           ...        ...        ...         ...
#  939      65      68    67.50          1.00      -0.09      -0.08       -0.09
#  940      67      68    67.60          1.00      -0.09      -0.08       -0.09
#  941      67      73    68.50          1.00      -0.09      -0.08       -0.09
#  942      67      69    68.33          1.00      -0.09      -0.08       -0.09
#  943      68      69    68.33          1.00      -0.09      -0.08       -0.09
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0        -0.30       1.05        0.37      -1.01       0.92       -0.02
#  1        -0.57       1.30        0.51      -1.58       1.02       -0.19
#  2        -1.15       0.99        0.37      -1.25       1.60       -0.60
#  3        -0.13       1.29        0.50      -1.42      -0.35       -0.84
#  4         0.01       1.39        0.42      -0.85       0.34       -0.32
#  ..         ...        ...         ...        ...        ...         ...
#  939       0.20       0.21        0.21       0.97       0.98        0.98
#  940       0.20       0.21        0.21       0.98       0.98        0.98
#  941       0.20       0.21        0.21       0.97       0.98        0.98
#  942       0.20       0.21        0.21       0.97       0.98        0.98
#  943       0.20       0.21        0.21       0.97       0.98        0.98
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  29
#  1                     0                     0  29
#  2                     0                     0  29
#  3                     0                     0  29
#  4                     0                     0  29
#  ..                  ...                   ...  ..
#  939                   1                     2  29
#  940                   1                     2  29
#  941                   1                     2  29
#  942                   1                     2  29
#  943                   1                     2  29
#
#  [944 rows x 16 columns],
#       Min_hr  Max_hr  Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  Mean_acc_x  \
#  0      68.0    73.0    70.33           NaN        NaN        NaN         NaN
#  1      68.0    68.0    68.00           NaN        NaN        NaN         NaN
#  2      67.0    73.0    68.50           NaN        NaN        NaN         NaN
#  3      67.0    74.0    69.83           NaN        NaN        NaN         NaN
#  4      65.0    66.0    65.17           NaN        NaN        NaN         NaN
#  ..      ...     ...      ...           ...        ...        ...         ...
#  714    70.0    71.0    70.17           1.0       -0.1      -0.09        -0.1
#  715    67.0    70.0    68.83           1.0       -0.1      -0.09        -0.1
#  716    68.0    70.0    68.83           1.0       -0.1      -0.09        -0.1
#  717    65.0    71.0    66.80           1.0       -0.1      -0.09        -0.1
#  718    67.0    68.0    67.67           1.0       -0.1      -0.09        -0.1
#
#       Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  Mean_acc_z  \
#  0          NaN        NaN         NaN        NaN        NaN         NaN
#  1          NaN        NaN         NaN        NaN        NaN         NaN
#  2          NaN        NaN         NaN        NaN        NaN         NaN
#  3          NaN        NaN         NaN        NaN        NaN         NaN
#  4          NaN        NaN         NaN        NaN        NaN         NaN
#  ..         ...        ...         ...        ...        ...         ...
#  714       0.54       0.54        0.54      -0.84      -0.84       -0.84
#  715       0.54       0.54        0.54      -0.84      -0.84       -0.84
#  716       0.54       0.54        0.54      -0.84      -0.84       -0.84
#  717       0.54       0.54        0.54      -0.84      -0.84       -0.84
#  718       0.54       0.54        0.54      -0.84      -0.84       -0.84
#
#       Etiquetas binarias  Etiquetas multiclase  ID
#  0                     0                     0  30
#  1                     0                     0  30
#  2                     0                     0  30
#  3                     0                     0  30
#  4                     0                     0  30
#  ..                  ...                   ...  ..
#  714                   0                     0  30
#  715                   0                     0  30
#  716                   0                     0  30
#  717                   0                     0  30
#  718                   0                     0  30
#
#  [719 rows x 16 columns]]

# %% [markdown]
# Como hay algunos valores NaN, se utiliza la siguiente funcion para **limpiar el dataframe** de NaN y valores infinitos:

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    
    return df[indices_to_keep].astype(np.float64)

# %%
clean_df = clean_dataset(pd.concat(df))

# %%
clean_df.describe()
# Out:
#              Min_hr        Max_hr       Mean_hr  Men_acc_sqrt     Min_acc_x  \
# count  22165.000000  22165.000000  22165.000000  22165.000000  22165.000000
# mean      63.286488     66.815024     64.952343      0.997740     -0.174443
# std        9.723944     10.852765     10.070385      0.005463      0.373352
# min       41.000000     42.000000     41.170000      0.950000     -1.740000
# 25%       56.000000     59.000000     57.830000      0.990000     -0.440000
# 50%       63.000000     66.000000     64.600000      1.000000     -0.250000
# 75%       69.000000     74.000000     71.170000      1.000000      0.060000
# max      127.000000    130.000000    128.570000      1.110000      0.970000
#
#           Max_acc_x    Mean_acc_x     Min_acc_y     Max_acc_y    Mean_acc_y  \
# count  22165.000000  22165.000000  22165.000000  22165.000000  22165.000000
# mean      -0.109587     -0.140973     -0.165641     -0.069474     -0.116628
# std        0.374379      0.352662      0.482825      0.498410      0.463681
# min       -0.940000     -0.970000     -2.610000     -1.000000     -1.000000
# 25%       -0.380000     -0.400000     -0.530000     -0.430000     -0.460000
# 50%       -0.190000     -0.220000     -0.140000     -0.040000     -0.110000
# 75%        0.100000      0.080000      0.170000      0.260000      0.200000
# max        3.250000      0.970000      0.990000      3.620000      0.990000
#
#           Min_acc_z     Max_acc_z    Mean_acc_z  Etiquetas binarias  \
# count  22165.000000  22165.000000  22165.000000        22165.000000
# mean      -0.521544     -0.438053     -0.484213            0.679630
# std        0.620723      0.638076      0.614174            0.466629
# min       -3.160000     -1.000000     -1.000000            0.000000
# 25%       -0.930000     -0.890000     -0.900000            0.000000
# 50%       -0.820000     -0.780000     -0.800000            1.000000
# 75%       -0.250000     -0.070000     -0.230000            1.000000
# max        0.990000      2.300000      1.000000            1.000000
#
#        Etiquetas multiclase            ID
# count          22165.000000  22165.000000
# mean               2.462441     14.312069
# std                1.515992      9.405430
# min                0.000000      0.000000
# 25%                2.000000      6.000000
# 50%                2.000000     14.000000
# 75%                3.000000     22.000000
# max                5.000000     30.000000

# %% [markdown]
# Se guarda en un dataframe el conjunto de características extraídas:

# %%
clean_df.to_csv('features.csv', header=True, index=False)

# %% [markdown]
# ### 3. Visualización datos dataframe

# %%
rows, columns = clean_df.shape #Forma de la BD
print ('La base de datos tiene', rows,'filas y',columns,'columnas\n')

print('Número de valores diferentes que hay para cada atributo:')
print(clean_df.nunique(),'\n')

print('Número de valores Null:')
print(clean_df.isnull().sum(),'\n')

print('Número de valores NaN:')
print(clean_df.isna().sum(),'\n')

print('Descriptores estadísticos:')
print(clean_df.describe().round(2),'\n')
# Out:
# La base de datos tiene 22165 filas y 16 columnas
#
# Número de valores diferentes que hay para cada atributo:
# Min_hr                   64
# Max_hr                   77
# Mean_hr                 894
# Men_acc_sqrt             14
# Min_acc_x               236
# Max_acc_x               238
# Mean_acc_x              178
# Min_acc_y               271
# Max_acc_y               284
# Mean_acc_y              200
# Min_acc_z               290
# Max_acc_z               248
# Mean_acc_z              201
# Etiquetas binarias        2
# Etiquetas multiclase      5
# ID                       31
# dtype: int64
#
# Número de valores Null:
# Min_hr                  0
# Max_hr                  0
# Mean_hr                 0
# Men_acc_sqrt            0
# Min_acc_x               0
# Max_acc_x               0
# Mean_acc_x              0
# Min_acc_y               0
# Max_acc_y               0
# Mean_acc_y              0
# Min_acc_z               0
# Max_acc_z               0
# Mean_acc_z              0
# Etiquetas binarias      0
# Etiquetas multiclase    0
# ID                      0
# dtype: int64
#
# Número de valores NaN:
# Min_hr                  0
# Max_hr                  0
# Mean_hr                 0
# Men_acc_sqrt            0
# Min_acc_x               0
# Max_acc_x               0
# Mean_acc_x              0
# Min_acc_y               0
# Max_acc_y               0
# Mean_acc_y              0
# Min_acc_z               0
# Max_acc_z               0
# Mean_acc_z              0
# Etiquetas binarias      0
# Etiquetas multiclase    0
# ID                      0
# dtype: int64
#
# Descriptores estadísticos:
#          Min_hr    Max_hr   Mean_hr  Men_acc_sqrt  Min_acc_x  Max_acc_x  \
# count  22165.00  22165.00  22165.00      22165.00   22165.00   22165.00
# mean      63.29     66.82     64.95          1.00      -0.17      -0.11
# std        9.72     10.85     10.07          0.01       0.37       0.37
# min       41.00     42.00     41.17          0.95      -1.74      -0.94
# 25%       56.00     59.00     57.83          0.99      -0.44      -0.38
# 50%       63.00     66.00     64.60          1.00      -0.25      -0.19
# 75%       69.00     74.00     71.17          1.00       0.06       0.10
# max      127.00    130.00    128.57          1.11       0.97       3.25
#
#        Mean_acc_x  Min_acc_y  Max_acc_y  Mean_acc_y  Min_acc_z  Max_acc_z  \
# count    22165.00   22165.00   22165.00    22165.00   22165.00   22165.00
# mean        -0.14      -0.17      -0.07       -0.12      -0.52      -0.44
# std          0.35       0.48       0.50        0.46       0.62       0.64
# min         -0.97      -2.61      -1.00       -1.00      -3.16      -1.00
# 25%         -0.40      -0.53      -0.43       -0.46      -0.93      -0.89
# 50%         -0.22      -0.14      -0.04       -0.11      -0.82      -0.78
# 75%          0.08       0.17       0.26        0.20      -0.25      -0.07
# max          0.97       0.99       3.62        0.99       0.99       2.30
#
#        Mean_acc_z  Etiquetas binarias  Etiquetas multiclase        ID
# count    22165.00            22165.00              22165.00  22165.00
# mean        -0.48                0.68                  2.46     14.31
# std          0.61                0.47                  1.52      9.41
# min         -1.00                0.00                  0.00      0.00
# 25%         -0.90                0.00                  2.00      6.00
# 50%         -0.80                1.00                  2.00     14.00
# 75%         -0.23                1.00                  3.00     22.00
# max          1.00                1.00                  5.00     30.00

# %% [markdown]
# **DIAGRAMA DE DISPERSIÓN**
#
# En el siguiente gráfico se puede ver, en la diagonal, el histograma de cada par de variables.
#
# El resto son diagramas de dispersión. La finalidad de estos es buscar si existe relación lineal o no lineal entre algún par de variables.

# %%
disper = sns.PairGrid(clean_df)
disper = disper.map_diag(plt.hist, alpha=0.7)
disper = disper.map_offdiag(plt.scatter, marker='.')

# %% [markdown]
# **MAPA DE CALOR**
#
# Diagrama que nos devuelve la relación lineal entre las variables.

# %%
f, ax = plt.subplots(figsize=(15,15))
corr = clean_df.corr()
#sns.heatmap(corr)
sns.heatmap(corr, annot=True, cmap="YlGnBu", xticklabels=corr.columns.values, yticklabels=corr.columns.values,square=True)

# %% [markdown]
# **DISTRIBUCCIÓN DE LAS ETIQUETAS EN EL CONJUNTO DE DATOS**

# %%
clean_df['Etiquetas binarias'].value_counts().plot.bar(title="BALANCEO DE CLASES BINARIAS")
plt.figure()
print(clean_df["Etiquetas binarias"].value_counts() )

plt.figure()
clean_df['Etiquetas multiclase'].value_counts().plot.bar(title="BALANCEO DE CLASES MULTICLASE")
print(clean_df["Etiquetas multiclase"].value_counts() )
# Out:
# 1.0    15064
# 0.0     7101
# Name: Etiquetas binarias, dtype: int64
# 2.0    10435
# 5.0     4529
# 3.0     3218
# 0.0     2572
# 1.0     1411
# Name: Etiquetas multiclase, dtype: int64
